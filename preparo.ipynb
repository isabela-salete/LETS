# %%
import pandas as pd
import numpy as np
import matplotlib_inline as plt

# %% [markdown]
# ## Montando dataset 2018

# %%
df2018_1 = pd.read_csv('dados\\2018\cat-jul-ago-set-2018.csv', encoding= 'ISO-8859-1', sep = ';') 
df2018_2 = pd.read_csv('dados\\2018\cat-comp-outnovdez-2018.csv', encoding= 'ISO-8859-1', sep = ';')

# %%
df2018_1.head()
# Out:
#   Agente  Causador  Acidente  Data Acidente     CBO                 CBO.1  \
# 0       Engrenagem - Disposi         201801  784205  784205-Alimentador d
# 1       Prensa - Maquina             201801  763210  763210-Costureiro na
# 2       Maquina, Nic                 201801  770105  770105-Mestre (Indús
# 3       Chao - Superficie Ut         201801  784205  784205-Alimentador d
# 4       Torre, Poste - Edifi         201801  715615  715615-Eletricista I
#
#    CID-10              CID-10.1  CNAE2.0 Empregador  CNAE2.0 Empregador.1  \
# 0  S681    S68.1 Amput Traum de                4763  Comercio Varejista d
# 1  S619    S61.9 Ferim do Punho                1412  Confeccao de Pecas d
# 2  M842    M84.2 Atraso de Cons                1621  Fabricacao de Madeir
# 3  S836    S83.6 Entorse Disten                4930  Transporte Rodoviari
# 4  Z540    Z54.0 Convalescenca                 4221  Obras para Geracao e
#
#            Emitente CAT  Espécie do benefício  ...  Parte Corpo Atingida  \
# ...

# %%
df2018_2.head()
# Out:
#   Agente  Causador  Acidente Data Acidente     CBO                 CBO.1  \
# 0       Maquina, Nic               2018/01  848520  848520-Magarefe
# 1       Esforco Excessivo, N       2018/01  514320  {ñ class}
# 2       Veiculo, Nic               2018/01  414110  414110-Armazenista
# 3       Asfalto, Alcatrao, P       2018/01  514205  514205-Coletor Lixo
# 4       Veiculo Rodoviario M       2018/02  782405  782405-Motorista de
#
#    CID-10              CID-10.1  CNAE2.0 Empregador  CNAE2.0 Empregador.1  \
# 0  S927    S92.7 Frat Mult do P                1012  Abate de Suinos, Ave
# 1  G560    G56.0 Sindr do Tunel                8610  Atividades de Atendi
# 2  S920    S92.0 Frat do Calcan                4930  Transporte Rodoviari
# 3  M255    M25.5 Dor Articular                 3811  Coleta de Residuos N
# 4  T920    T92.0 Sequelas de Fe                4921  Transporte Rodoviari
#
#            Emitente CAT  Espécie do benefício  ...  Parte Corpo Atingida  \
# ...

# %%
df2018_1.columns
# Out:
# Index(['Agente  Causador  Acidente', 'Data Acidente', 'CBO', 'CBO.1', 'CID-10',
#        'CID-10.1', 'CNAE2.0 Empregador', 'CNAE2.0 Empregador.1',
#        'Emitente CAT', 'Espécie do benefício', 'Filiação Segurado',
#        'Indica Óbito Acidente', 'Munic Empr', 'Natureza da Lesão',
#        'Origem de Cadastramento CAT', 'Parte Corpo Atingida', 'Sexo',
#        'Tipo do Acidente', 'UF  Munic.  Acidente', 'UF Munic. Empregador',
#        'Data  Afastamento', 'Data Despacho Benefício', 'Data Acidente.1',
#        'Data Nascimento', 'Data Emissão CAT'],
#       dtype='object')

# %%
df2018_2.columns
# Out:
# Index(['Agente  Causador  Acidente', 'Data Acidente', 'CBO', 'CBO.1', 'CID-10',
#        'CID-10.1', 'CNAE2.0 Empregador', 'CNAE2.0 Empregador.1',
#        'Emitente CAT', 'Espécie do benefício', 'Filiação Segurado',
#        'Indica acidente', 'Munic Empr', 'Natureza da Lesão',
#        'Origem de Cadastramento CAT', 'Parte Corpo Atingida', 'Sexo',
#        'Tipo do Acidente', 'UF  Munic.  Acidente', 'UF Munic. Empregador',
#        'Data  Afastamento', 'Data Despacho Benefício', 'Data Acidente.1',
#        'Data Nascimento', 'Data Emissão CAT'],
#       dtype='object')

# %%
df2018_1['Indica Óbito Acidente']
# Out:
# 0         Não
# 1         Não
# 2         Não
# 3         Não
# 4         Não
#                   ...
# 122593    Não
# 122594    Não
# 122595    Não
# 122596    Não
# 122597    Não
# Name: Indica Óbito Acidente, Length: 122598, dtype: object

# %%
df2018_2['Indica acidente']
# Out:
# 0         Não
# 1         Não
# 2         Não
# 3         Não
# 4         Não
#                   ...
# 119213    Não
# 119214    Não
# 119215    Não
# 119216    Não
# 119217    Não
# Name: Indica acidente, Length: 119218, dtype: object

# %%
df2018_1.rename(columns={'Indica Óbito Acidente': 'Indica acidente'}, inplace = True)

# %%
df2018_1.columns.equals(df2018_2.columns)
# Out:
# True

# %%
df2018_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122598 entries, 0 to 122597
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Agente  Causador  Acidente   122598 non-null  object
#  1   Data Acidente                122598 non-null  int64
#  2   CBO                          122598 non-null  int64
#  3   CBO.1                        122598 non-null  object
#  4   CID-10                       122598 non-null  object
#  5   CID-10.1                     122598 non-null  object
#  6   CNAE2.0 Empregador           122598 non-null  int64
#  7   CNAE2.0 Empregador.1         122598 non-null  object
#  8   Emitente CAT                 122598 non-null  object
#  9   Espécie do benefício         122598 non-null  object
#  10  Filiação Segurado            122598 non-null  object
#  11  Indica acidente              122598 non-null  object
# ...

# %%
df2018_1['Data Despacho Benefício']
# Out:
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
#            ...
# 122593    201809
# 122594    201809
# 122595    201809
# 122596    201809
# 122597    201810
# Name: Data Despacho Benefício, Length: 122598, dtype: int64

# %%
df2018_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119218 entries, 0 to 119217
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Agente  Causador  Acidente   119218 non-null  object
#  1   Data Acidente                119218 non-null  object
#  2   CBO                          119218 non-null  int64
#  3   CBO.1                        119218 non-null  object
#  4   CID-10                       119218 non-null  object
#  5   CID-10.1                     119218 non-null  object
#  6   CNAE2.0 Empregador           119218 non-null  int64
#  7   CNAE2.0 Empregador.1         119218 non-null  object
#  8   Emitente CAT                 119218 non-null  object
#  9   Espécie do benefício         119218 non-null  object
#  10  Filiação Segurado            119218 non-null  object
#  11  Indica acidente              119218 non-null  object
# ...

# %%
df2018 = pd.concat([df2018_1, df2018_2])

# %%
print(f"O dataframe 2018_1 tinha {df2018_1.shape[0]} linhas")
print(f"O dataframe 2018_2 tinha {df2018_2.shape[0]} linhas")
print(f"O dataframe final para 2018 tem {df2018.shape[0]} linhas")
# Out:
# O dataframe 2018_1 tinha 122598 linhas
# O dataframe 2018_2 tinha 119218 linhas
# O dataframe final para 2018 tem 241816 linhas

# %%
df2018.head()
# Out:
#   Agente  Causador  Acidente Data Acidente     CBO                 CBO.1  \
# 0       Engrenagem - Disposi        201801  784205  784205-Alimentador d
# 1       Prensa - Maquina            201801  763210  763210-Costureiro na
# 2       Maquina, Nic                201801  770105  770105-Mestre (Indús
# 3       Chao - Superficie Ut        201801  784205  784205-Alimentador d
# 4       Torre, Poste - Edifi        201801  715615  715615-Eletricista I
#
#    CID-10              CID-10.1  CNAE2.0 Empregador  CNAE2.0 Empregador.1  \
# 0  S681    S68.1 Amput Traum de                4763  Comercio Varejista d
# 1  S619    S61.9 Ferim do Punho                1412  Confeccao de Pecas d
# 2  M842    M84.2 Atraso de Cons                1621  Fabricacao de Madeir
# 3  S836    S83.6 Entorse Disten                4930  Transporte Rodoviari
# 4  Z540    Z54.0 Convalescenca                 4221  Obras para Geracao e
#
#            Emitente CAT  Espécie do benefício  ...  Parte Corpo Atingida  \
# ...

# %%
df2018['Munic Empr'].value_counts()
# Out:
# Munic Empr
# 355030-São Paulo        25448
# 330455-Rio de Janeir     9412
# 310620-Belo Horizont     5256
# 410690-Curitiba          5008
# 431490-Porto Alegre      4484
#                         ...
# 314140-Medina               1
# 130130-Codajás              1
# 130310-Nova Olinda d        1
# 260260-Brejo da Madr        1
# 261500-Taquaritinga         1
# Name: count, Length: 3659, dtype: int64

# %%
df2018.loc[(df2018['Munic Empr'] == '330420-Resende      ')]
# Out:
#        Agente  Causador  Acidente Data Acidente     CBO                 CBO.1  \
# 716          Cadeira Banco - Mobi        201806  123110  123110-Dir. Administ
# 1742         Particulas - nao Ide        201806  514320  {ñ class}
# 2134         Ferramenta Manual se        201807  322205  322205-Tec. de Enfer
# 3408         Animal Vivo                 201806  724410  724410-Caldeireiro (
# 4181         Ferramenta Manual se        201807  514310  {ñ class}
# ...                           ...           ...     ...                   ...
# 112541       Rua e Estrada - Supe       2018/12  519110  519110-Motociclista
# 113403       Equip. de Aqueciment       2018/12  514320  {ñ class}
# 113550       Veiculo, Nic               2018/12  725505  725505-Montador de V
# 116460       Serra - Maquina            2018/12  521125  521125-Repositor de
# 118307       Cortadeira, Guilhoti       2018/12  513425  513425-Copeiro
#
#         CID-10              CID-10.1  CNAE2.0 Empregador  \
# ...

# %%
#Filtro Resende
filtro_resende = df2018['Munic Empr'].str.contains('Resende', na=False)
df_resende2018 = df2018.loc[filtro_resende, 'Munic Empr']

#Filtro Itatiaia
filtro_itatiaia = df2018['Munic Empr'].str.contains('Itatiaia', na=False)
df_itatiaia2018 = df2018.loc[filtro_itatiaia, 'Munic Empr']

#Filtro Porto Real
filtro_pr = df2018['Munic Empr'].str.contains('Porto Real', na=False)
df_pr2018 = df2018.loc[filtro_pr, 'Munic Empr']

#Filtro Quatis
filtro_quatis = df2018['Munic Empr'].str.contains('Quatis', na=False)
df_quatis2018 = df2018.loc[filtro_quatis, 'Munic Empr']

#Filtro Barra do Piraí
filtro_barrapirai = df2018['Munic Empr'].str.contains('Barra do Pi', na=False)
df_barrapirai2018 = df2018.loc[filtro_barrapirai, 'Munic Empr']

#Filtro Barra Mansa
filtro_barramansa = df2018['Munic Empr'].str.contains('Barra Mansa', na=False)
df_barramansa2018 = df2018.loc[filtro_barramansa, 'Munic Empr']

#Filtro Pinheiral
filtro_pinheiral= df2018['Munic Empr'].str.contains('Pinheiral', na=False)
df_pinheiral2018 = df2018.loc[filtro_pinheiral, 'Munic Empr']

#Filtro Piraí
filtro_pirai = df2018['Munic Empr'].str.contains('Piraí', na=False)
df_pirai2018 = df2018.loc[filtro_pirai, 'Munic Empr']

#Filtro Rio Claro
filtro_rioclaro = df2018['Munic Empr'].str.contains('Rio Claro', na=False)
df_rioclaro2018 = df2018.loc[filtro_rioclaro, 'Munic Empr']

#Filtro Rio das Flores
filtro_riodasflores = df2018['Munic Empr'].str.contains('Rio das', na=False)
df_riodasflores2018 = df2018.loc[filtro_riodasflores, 'Munic Empr']

#Filtro Valença
filtro_valença = df2018['Munic Empr'].str.contains('Valença', na=False)
df_valença2018 = df2018.loc[filtro_valença, 'Munic Empr']

#Filtro Volta Redonda
filtro_voltaredonda = df2018['Munic Empr'].str.contains('Volta Redonda', na=False)
df_voltaredonda2018 = df2018.loc[filtro_voltaredonda, 'Munic Empr']

# %%
print(f'{df_resende2018.unique()}\n, {df_itatiaia2018.unique()}\n, {df_pr2018.unique()}\n, {df_quatis2018.unique()}\n,{df_barrapirai2018.unique()},{df_barramansa2018.unique()}\n, {df_pinheiral2018.unique()}\n, {df_pirai2018.unique()}\n, {df_rioclaro2018.unique()}\n, {df_riodasflores2018.unique()}\n, {df_valença2018.unique()}\n, {df_voltaredonda2018.unique()}')
# Out:
# ['330420-Resende      ' '314510-Nova Resende ' '315420-Resende Costa']
# , ['330225-Itatiaia     ']
# , ['330411-Porto Real   ' '270750-Porto Real do']
# , ['330412-Quatis       ']
# ,['330030-Barra do Pira'],['330040-Barra Mansa  ']
# , ['330395-Pinheiral    ']
# , ['330400-Piraí        ' '411940-Piraí do Sul ']
# , ['354390-Rio Claro-Sp ' '330440-Rio Claro-Rj ']
# , ['354400-Rio das Pedra' '330452-Rio das Ostra' '330450-Rio das Flore'
#  '421440-Rio das Antas']
# , ['330610-Valença-Rj   ' '293290-Valença-Ba   ' '221130-Valença do Pi']
# , ['330630-Volta Redonda']

# %%
print(f'Variáveis dos municípios: \n{df_resende2018.max()},\n{df_itatiaia2018.max()},\n{df_pr2018.max()},\n{df_quatis2018.max()}.')
# Out:
# Variáveis dos municípios:
# 330420-Resende      ,
# 330225-Itatiaia     ,
# 330411-Porto Real   ,
# 330412-Quatis       .

# %%
municipios_desejados = ['330420-Resende      ', '330225-Itatiaia     ', '330411-Porto Real   ', 
'330412-Quatis       ', '330040-Barra Mansa  ', '330030-Barra do Pira', '330395-Pinheiral    ', 
'330400-Piraí        ', '330440-Rio Claro-Rj ', '330450-Rio das Flore','330610-Valença-Rj   ',
'330630-Volta Redonda']
df_fim2018 = df2018[df2018['Munic Empr'].isin(municipios_desejados)]
df_fim2018.head()
# Out:
#      Agente  Causador  Acidente Data Acidente     CBO                 CBO.1  \
# 681        Madeira (Toro, Madei        201807  782515  782515-Motorista Ope
# 709        Fogo-Chama,Material         201807  862150  862150-Oper. Máquina
# 716        Cadeira Banco - Mobi        201806  123110  123110-Dir. Administ
# 998        Ferramenta Manual se        201806  514325  {ñ class}
# 1512       Laminadora, Calandra        201806  862150  862150-Oper. Máquina
#
#       CID-10              CID-10.1  CNAE2.0 Empregador  CNAE2.0 Empregador.1  \
# 681   W22     W22   Impacto Acid A                4930  Transporte Rodoviari
# 709   T252    T25.2 Queim de 2.Gra                2422  Producao de Laminado
# 716   S635    S63.5 Entorse e Dist                8411  Administracao Public
# 998   Z209    Z20.9 Contato Exposi                8121  Limpeza em Predios e
# 1512  S600    S60.0 Contusao de De                2854  Fabricacao de Maquin
#
# ...

# %%
df_fim2018['Munic Empr'].unique()
# Out:
# array(['330630-Volta Redonda', '330420-Resende      ',
#        '330225-Itatiaia     ', '330030-Barra do Pira',
#        '330411-Porto Real   ', '330400-Piraí        ',
#        '330040-Barra Mansa  ', '330610-Valença-Rj   ',
#        '330412-Quatis       ', '330450-Rio das Flore',
#        '330395-Pinheiral    ', '330440-Rio Claro-Rj '], dtype=object)

# %% [markdown]
# ### Certa inconscistência nos dados

# %%
df_fim2018['UF  Munic.  Acidente'].value_counts()
# Out:
# UF  Munic.  Acidente
# Tocantins               926
# Maranhão                 13
# {ñ class}                 7
# Rondônia                  3
# Roraima                   2
# Name: count, dtype: int64

# %%
df2018['UF  Munic.  Acidente'].value_counts()
# Out:
# UF  Munic.  Acidente
# Maranhão                89037
# {ñ class}               74129
# Rondônia                24133
# Roraima                 19453
# Tocantins               16426
# Pará                     5137
# Acre                     4043
# Ceará                    3039
# Pernambuco               1724
# Amazonas                 1421
# Piauí                    1047
# Amapá                     712
# Sergipe                   650
# Alagoas                   315
# Rio Grande Norte          291
# Paraíba                   259
# Name: count, dtype: int64

# %% [markdown]
# ## Montando dataset 2019

# %%
df2019_1 = pd.read_csv('dados\\2019\cat2018-comp01-02-03-2019.csv', encoding= 'ISO-8859-1', sep = ';') 
df2019_2 = pd.read_csv('dados\\2019\cat-comp04-05-06-2019.csv', encoding= 'ISO-8859-1', sep = ';') 
df2019_3 = pd.read_csv('dados\\2019\cat-comp07-08-09-2019.csv', encoding= 'ISO-8859-1', sep = ';') 
df2019_4 = pd.read_csv('dados\\2019\cat-comp10-11-12-2019.csv', encoding= 'ISO-8859-1', sep = ';')

# %% [markdown]
# ### Verificação das datas

# %%
print(f"Período de df1: {df2019_1['Data Acidente.1'].min()} a {df2019_1['Data Acidente.1'].max()}")
print(f"Período de df2: {df2019_2['Data Acidente.1'].min()} a {df2019_2['Data Acidente.1'].max()}")
print(f"Período de df3: {df2019_3['Data Acidente.1'].min()} a {df2019_3['Data Acidente.1'].max()}")
print(f"Período de df4: {df2019_4['Data Acidente.1'].min()} a {df2019_4['Data Acidente.1'].max()}")
# Out:
# Período de df1: 01/01/2019 a 31/03/2019
# Período de df2: 01/01/2019 a 31/05/2019
# Período de df3: 01/01/2019 a 31/08/2019
# Período de df4: 01/01/2019 a 31/12/2019

# %% [markdown]
# ### Verificação dos nomes das Colunas

# %%
df2019_1.columns
# Out:
# Index(['Agente  Causador  Acidente', 'Data Acidente', 'CBO', 'CBO.1', 'CID-10',
#        'CID-10.1', 'CNAE2.0 Empregador', 'CNAE2.0 Empregador.1',
#        'Emitente CAT', 'Espécie do benefício', 'Filiação Segurado',
#        'Indica acidente', 'Munic Empr', 'Natureza da Lesão',
#        'Origem de Cadastramento CAT', 'Parte Corpo Atingida', 'Sexo',
#        'Tipo do Acidente', 'UF  Munic.  Acidente', 'UF Munic. Empregador',
#        'Data  Afastamento', 'Data Despacho Benefício', 'Data Acidente.1',
#        'Data Nascimento', 'Data Emissão CAT'],
#       dtype='object')

# %%
df2019_1.columns.equals(df2019_2.columns)
# Out:
# True

# %%
df2019_1.columns.equals(df2019_3.columns)
# Out:
# True

# %%
df2019_1.columns.equals(df2019_4.columns)
# Out:
# True

# %% [markdown]
# ### Informações sobre os datasets

# %%
df2019_1.info()
df2019_2.info() 
df2019_3.info()
df2019_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110798 entries, 0 to 110797
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Agente  Causador  Acidente   110798 non-null  object
#  1   Data Acidente                110798 non-null  object
#  2   CBO                          110798 non-null  int64
#  3   CBO.1                        110798 non-null  object
#  4   CID-10                       110798 non-null  object
#  5   CID-10.1                     110798 non-null  object
#  6   CNAE2.0 Empregador           110798 non-null  int64
#  7   CNAE2.0 Empregador.1         110798 non-null  object
#  8   Emitente CAT                 110798 non-null  object
#  9   Espécie do benefício         110798 non-null  object
#  10  Filiação Segurado            110798 non-null  object
#  11  Indica acidente              110798 non-null  object
# ...

# %% [markdown]
# ### Concatenação do dataset 2019

# %%
df2019_concat = pd.concat([df2019_1, df2019_2, df2019_3, df2019_4])

# %%
print(f"O dataframe 2019_1 tinha {df2019_1.shape[0]} linhas")
print(f"O dataframe 2019_2 tinha {df2019_2.shape[0]} linhas")
print(f"O dataframe 2019_3 tinha {df2019_3.shape[0]} linhas")
print(f"O dataframe 2019_4 tinha {df2019_4.shape[0]} linhas")
print(f"O dataframe final para 2019 tem {df2019_concat.shape[0]} linhas")
# Out:
# O dataframe 2019_1 tinha 110798 linhas
# O dataframe 2019_2 tinha 122831 linhas
# O dataframe 2019_3 tinha 127546 linhas
# O dataframe 2019_4 tinha 113433 linhas
# O dataframe final para 2019 tem 474608 linhas

# %% [markdown]
# ### Filtragem

# %%
#Filtro Resende
filtro_resende = df2019_concat['Munic Empr'].str.contains('Resende', na=False)
df_resende2019 = df2019_concat.loc[filtro_resende, 'Munic Empr']

#Filtro Itatiaia
filtro_itatiaia = df2019_concat['Munic Empr'].str.contains('Itatiaia', na=False)
df_itatiaia2019 = df2019_concat.loc[filtro_itatiaia, 'Munic Empr']

#Filtro Porto Real
filtro_pr = df2019_concat['Munic Empr'].str.contains('Porto Real', na=False)
df_pr2019 = df2019_concat.loc[filtro_pr, 'Munic Empr']

#Filtra Quatis
filtro_quatis = df2019_concat['Munic Empr'].str.contains('Quatis', na=False)
df_quatis2019 = df2019_concat.loc[filtro_quatis, 'Munic Empr']

#Filtro Barra do Piraí
filtro_barrapirai = df2019_concat['Munic Empr'].str.contains('Barra do Pi', na=False)
df_barrapirai2019 = df2019_concat.loc[filtro_barrapirai, 'Munic Empr']

#Filtro Barra Mansa
filtro_barramansa = df2019_concat['Munic Empr'].str.contains('Barra Mansa', na=False)
df_barramansa2019 = df2019_concat.loc[filtro_barramansa, 'Munic Empr']

#Filtro Pinheiral
filtro_pinheiral= df2019_concat['Munic Empr'].str.contains('Pinheiral', na=False)
df_pinheiral2019 = df2019_concat.loc[filtro_pinheiral, 'Munic Empr']

#Filtro Piraí
filtro_pirai = df2019_concat['Munic Empr'].str.contains('Piraí', na=False)
df_pirai2019 = df2019_concat.loc[filtro_pirai, 'Munic Empr']

#Filtro Rio Claro
filtro_rioclaro = df2019_concat['Munic Empr'].str.contains('Rio Claro', na=False)
df_rioclaro2019 = df2019_concat.loc[filtro_rioclaro, 'Munic Empr']

#Filtro Rio das Flores
filtro_riodasflores = df2019_concat['Munic Empr'].str.contains('Rio das', na=False)
df_riodasflores2019 = df2019_concat.loc[filtro_riodasflores, 'Munic Empr']

#Filtro Valença
filtro_valença = df2019_concat['Munic Empr'].str.contains('Valença', na=False)
df_valença2019 = df2019_concat.loc[filtro_valença, 'Munic Empr']

#Filtro Volta Redonda
filtro_voltaredonda = df2019_concat['Munic Empr'].str.contains('Volta Redonda', na=False)
df_voltaredonda2019 = df2019_concat.loc[filtro_voltaredonda, 'Munic Empr']

# %%
df_pinheiral2019.unique()
# Out:
# (array(['330395-Pinheiral    '], dtype=object),
#  Munic Empr
#  330225-Itatiaia         68
#  Name: count, dtype: int64,
#  Munic Empr
#  330412-Quatis           3
#  Name: count, dtype: int64,
#  Munic Empr
#  330411-Porto Real       87
#  Name: count, dtype: int64)

# %% [markdown]
# Os códigos das cidades permanecem os mesmos

# %% [markdown]
# ### Filtragem no DataSet pelo município

# %%
municipios_desejados = ['330420-Resende      ', '330225-Itatiaia     ', '330411-Porto Real   ', 
'330412-Quatis       ', '330040-Barra Mansa  ', '330030-Barra do Pira', '330395-Pinheiral    ', 
'330400-Piraí        ', '330440-Rio Claro-Rj ', '330450-Rio das Flore','330610-Valença-Rj   ',
'330630-Volta Redonda']
df_fim2019 = df2019_concat[df2019_concat['Munic Empr'].isin(municipios_desejados)]
display(df_fim2019)
# Out:
#        Agente  Causador  Acidente Data Acidente     CBO                 CBO.1  \
# 151          Corda, Cabo, Corrent       2019/01  911305  911305-Mec. Manut. M
# 252          Produto Biologico (S       2019/01  322205  322205-Tec. de Enfer
# 288          Escada Permanente Cu       2019/01  421125  421125-Oper. Caixa
# 1546         Embalagem e Recipien       2019/01  784205  784205-Alimentador d
# 2223         Chao - Superficie Ut       2019/01  322205  322205-Tec. de Enfer
# ...                           ...           ...     ...                   ...
# 112491       Empilhadeira               2019/12  414105  414105-Almoxarife
# 112526       Ceramica                   2019/12  521105  521105-Vendedor em C
# 112788       Queda de Pes. com Di       2019/12  322205  322205-Tec. de Enfer
# 112984       Chao - Superficie Ut       2019/12  521125  521125-Repositor de
# 112987       Faca, Facao- Ferrame       2019/12  782510  782510-Motorista de
#
# ...

# %%
df_fim2019['Munic Empr'].unique()
# Out:
# array(['330630-Volta Redonda', '330040-Barra Mansa  ',
#        '330420-Resende      ', '330411-Porto Real   ',
#        '330400-Piraí        ', '330030-Barra do Pira',
#        '330225-Itatiaia     ', '330395-Pinheiral    ',
#        '330412-Quatis       ', '330610-Valença-Rj   ',
#        '330450-Rio das Flore', '330440-Rio Claro-Rj '], dtype=object)

# %%
df_fim2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1881 entries, 151 to 112987
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Agente  Causador  Acidente   1881 non-null   object
#  1   Data Acidente                1881 non-null   object
#  2   CBO                          1881 non-null   int64
#  3   CBO.1                        1881 non-null   object
#  4   CID-10                       1881 non-null   object
#  5   CID-10.1                     1881 non-null   object
#  6   CNAE2.0 Empregador           1881 non-null   int64
#  7   CNAE2.0 Empregador.1         1881 non-null   object
#  8   Emitente CAT                 1881 non-null   object
#  9   Espécie do benefício         1881 non-null   object
#  10  Filiação Segurado            1881 non-null   object
#  11  Indica acidente              1881 non-null   object
#  12  Munic Empr                   1881 non-null   object
# ...

# %% [markdown]
# ### Verificação da mesma inconscistência

# %%
df_fim2019['UF  Munic.  Acidente'].value_counts()
# Out:
# UF  Munic.  Acidente
# Tocantins               1831
# Maranhão                  22
# Rondônia                  14
# {ñ class}                 11
# Amapá                      1
# Roraima                    1
# Amazonas                   1
# Name: count, dtype: int64

# %% [markdown]
# ## Montando o dataset 2020

# %%
df2020_1 = pd.read_csv('dados\\2020\cat-comp01-02-03-2020.csv', encoding= 'ISO-8859-1', sep = ';') 
df2020_2 = pd.read_csv('dados\\2020\cat-competencia-04-05-06-2020.csv', encoding= 'ISO-8859-1', sep = ';') 
df2020_3 = pd.read_csv('dados\\2020\cat-competencia-07-08-09-2020.csv', encoding= 'ISO-8859-1', sep = ';') 
df2020_4 = pd.read_csv('dados\\2020\cat-comp10-11-12-2020.csv', encoding= 'ISO-8859-1', sep = ';')

# %% [markdown]
# ### Verificação dos nomes das colunas

# %%
print(f'As colunas em df1 e df2 são iguais: {df2020_1.columns.equals(df2020_2.columns)}')
print(f'As colunas em df2 e df3 são iguais: {df2020_2.columns.equals(df2020_3.columns)}')
print(f'As colunas em df3 e df4 são iguais: {df2020_3.columns.equals(df2020_4.columns)}')
# Out:
# As colunas em df1 e df2 são iguais: False
# As colunas em df2 e df3 são iguais: True
# As colunas em df3 e df4 são iguais: True

# %%
df2020_1.columns
# Out:
# Index(['Agente  Causador  Acidente', 'Data Acidente', 'CBO', 'CBO.1', 'CID-10',
#        'CID-10.1', 'CNAE2.0 Empregador', 'CNAE2.0 Empregador.1',
#        'Emitente CAT', 'Espécie do benefício', 'Filiação Segurado',
#        'Indica acidente', 'Munic Empr', 'Natureza da Lesão',
#        'Origem de Cadastramento CAT', 'Parte Corpo Atingida', 'Sexo',
#        'Tipo do Acidente', 'UF  Munic.  Acidente', 'UF Munic. Empregador',
#        'Data  Afastamento', 'Data Despacho Benefício', 'Data Acidente.1',
#        'Data Nascimento', 'Data Emissão CAT'],
#       dtype='object')

# %%
df2020_2.columns
# Out:
# Index(['ï»¿Agente  Causador  Acidente', 'Data Acidente', 'CBO', 'CBO_1',
#        'CID-10', 'CID-10_2', 'CNAE2.0 Empregador', 'CNAE2.0 Empregador_3',
#        'Emitente CAT', 'EspÃ©cie do benefÃ­cio', 'FiliaÃ§Ã£o Segurado',
#        'Indica acidente', 'Munic Empr', 'Natureza da LesÃ£o',
#        'Origem de Cadastramento CAT', 'Parte Corpo Atingida', 'Sexo',
#        'Tipo do Acidente', 'UF  Munic.  Acidente', 'UF Munic. Empregador',
#        'Data  Afastamento', 'Data Despacho BenefÃ­cio', 'Data Acidente_4',
#        'Data Nascimento', 'Data EmissÃ£o CAT'],
#       dtype='object')

# %%
df2020_2.rename(columns={'ï»¿Agente  Causador  Acidente': 'Agente  Causador  Acidente'}, inplace = True)
df2020_2.rename(columns={'CBO_1': 'CBO.1'}, inplace = True)
df2020_2.rename(columns={'CID-10_2': 'CID-10.1'}, inplace = True)
df2020_2.rename(columns={'CNAE2.0 Empregador_3': 'CNAE2.0 Empregador.1'}, inplace = True)
df2020_2.rename(columns={'EspÃ©cie do benefÃ­cio': 'Espécie do benefício'}, inplace = True)
df2020_2.rename(columns={'FiliaÃ§Ã£o Segurado': 'Filiação Segurado'}, inplace = True)
df2020_2.rename(columns={'Natureza da LesÃ£o': 'Natureza da Lesão'}, inplace = True)
df2020_2.rename(columns={'Data Despacho BenefÃ­cio': 'Data Despacho Benefício'}, inplace = True)
df2020_2.rename(columns={'Data Acidente_4': 'Data Acidente.1'}, inplace = True)
df2020_2.rename(columns={'Data EmissÃ£o CAT': 'Data Emissão CAT'}, inplace = True)

df2020_3.rename(columns={'ï»¿Agente  Causador  Acidente': 'Agente  Causador  Acidente'}, inplace = True)
df2020_3.rename(columns={'CBO_1': 'CBO.1'}, inplace = True)
df2020_3.rename(columns={'CID-10_2': 'CID-10.1'}, inplace = True)
df2020_3.rename(columns={'CNAE2.0 Empregador_3': 'CNAE2.0 Empregador.1'}, inplace = True)
df2020_3.rename(columns={'EspÃ©cie do benefÃ­cio': 'Espécie do benefício'}, inplace = True)
df2020_3.rename(columns={'FiliaÃ§Ã£o Segurado': 'Filiação Segurado'}, inplace = True)
df2020_3.rename(columns={'Natureza da LesÃ£o': 'Natureza da Lesão'}, inplace = True)
df2020_3.rename(columns={'Data Despacho BenefÃ­cio': 'Data Despacho Benefício'}, inplace = True)
df2020_3.rename(columns={'Data Acidente_4': 'Data Acidente.1'}, inplace = True)
df2020_3.rename(columns={'Data EmissÃ£o CAT': 'Data Emissão CAT'}, inplace = True)

df2020_4.rename(columns={'ï»¿Agente  Causador  Acidente': 'Agente  Causador  Acidente'}, inplace = True)
df2020_4.rename(columns={'CBO_1': 'CBO.1'}, inplace = True)
df2020_4.rename(columns={'CID-10_2': 'CID-10.1'}, inplace = True)
df2020_4.rename(columns={'CNAE2.0 Empregador_3': 'CNAE2.0 Empregador.1'}, inplace = True)
df2020_4.rename(columns={'EspÃ©cie do benefÃ­cio': 'Espécie do benefício'}, inplace = True)
df2020_4.rename(columns={'FiliaÃ§Ã£o Segurado': 'Filiação Segurado'}, inplace = True)
df2020_4.rename(columns={'Natureza da LesÃ£o': 'Natureza da Lesão'}, inplace = True)
df2020_4.rename(columns={'Data Despacho BenefÃ­cio': 'Data Despacho Benefício'}, inplace = True)
df2020_4.rename(columns={'Data Acidente_4': 'Data Acidente.1'}, inplace = True)
df2020_4.rename(columns={'Data EmissÃ£o CAT': 'Data Emissão CAT'}, inplace = True)

# %%
print(f'As colunas em df1 e df2 são iguais: {df2020_1.columns.equals(df2020_2.columns)}')
print(f'As colunas em df2 e df3 são iguais: {df2020_2.columns.equals(df2020_3.columns)}')
print(f'As colunas em df3 e df4 são iguais: {df2020_3.columns.equals(df2020_4.columns)}')
# Out:
# As colunas em df1 e df2 são iguais: True
# As colunas em df2 e df3 são iguais: True
# As colunas em df3 e df4 são iguais: True

# %% [markdown]
# ### Verificação das datas

# %%
print(f"Período de df1: {df2020_1['Data Acidente.1'].min()} a {df2020_1['Data Acidente.1'].max()}")
print(f"Período de df2: {df2020_2['Data Acidente.1'].min()} a {df2020_2['Data Acidente.1'].max()}")
print(f"Período de df3: {df2020_3['Data Acidente.1'].min()} a {df2020_3['Data Acidente.1'].max()}")
print(f"Período de df4: {df2020_4['Data Acidente.1'].min()} a {df2020_4['Data Acidente.1'].max()}")
# Out:
# Período de df1:  {ñ class} a 31/12/2019
# Período de df2: 01/01/2020 a 31/05/2020
# Período de df3: 01/01/2020 a 31/08/2020
# Período de df4: 01/01/2020 a 31/12/2020

# %%
df2020_1['Data Acidente.1'].min()
# Out:
# ' {ñ class}'

# %%
df2020_1.loc[(df2020_1['Data Acidente.1']) == ' {ñ class}']
# Out:
#       Agente  Causador  Acidente Data Acidente     CBO                 CBO.1  \
# 1573        Reacao do Corpo a Mo       *******  763125  {ñ class}
# 3629        Caixa, Engradado, Ca       *******  848520  848520-Magarefe
# 6546        Barril, Barrica, Bar       *******  514205  514205-Coletor Lixo
# 9932        Energia                    *******  724115  724115-Inst. Tubulaç
# 10366       Forno, Estufa, Retor       *******  513205  513205-Cozinheiro Ge
# 11128       Faca, Facao- Ferrame       *******  848505  848505-Abatedor
# 11510       Alicate, Torques, Te       *******  322205  322205-Tec. de Enfer
#
#        CID-10              CID-10.1  CNAE2.0 Empregador  CNAE2.0 Empregador.1  \
# 1573   S300    S30.0 Contusao do Do                7820  Locacao de Mao-De-Ob
# 3629   S602    S60.2 Contusao de Ou                1012  Abate de Suinos, Ave
# 6546   S826    S82.6 Frat do Maleol                4930  Transporte Rodoviari
# ...

# %% [markdown]
# Mantidos pois há data de emissão do CAT

# %% [markdown]
# ### Contatenação do DataSet

# %%
df2020_concat = pd.concat([df2020_1, df2020_2, df2020_3, df2020_4])

# %%
print(f"O dataframe 2020_1 tinha {df2020_1.shape[0]} linhas")
print(f"O dataframe 2020_2 tinha {df2020_2.shape[0]} linhas")
print(f"O dataframe 2020_3 tinha {df2020_3.shape[0]} linhas")
print(f"O dataframe 2020_4 tinha {df2020_4.shape[0]} linhas")
print(f"O dataframe final para 2020 tem {df2020_concat.shape[0]} linhas")
# Out:
# O dataframe 2020_1 tinha 81264 linhas
# O dataframe 2020_2 tinha 75743 linhas
# O dataframe 2020_3 tinha 117439 linhas
# O dataframe 2020_4 tinha 116945 linhas
# O dataframe final para 2020 tem 391391 linhas

# %% [markdown]
# ### Filtragem

# %%
#Filtro Resende
filtro_resende = df2020_concat['Munic Empr'].str.contains('Resende', na=False)
df_resende2020 = df2020_concat.loc[filtro_resende, 'Munic Empr']

#Filtro Itatiaia
filtro_itatiaia = df2020_concat['Munic Empr'].str.contains('Itatiaia', na=False)
df_itatiaia2020 = df2020_concat.loc[filtro_itatiaia, 'Munic Empr']

#Filtro Porto Real
filtro_pr = df2020_concat['Munic Empr'].str.contains('Porto Real', na=False)
df_pr2020 = df2020_concat.loc[filtro_pr, 'Munic Empr']

#Filtra Quatis
filtro_quatis = df2020_concat['Munic Empr'].str.contains('Quatis', na=False)
df_quatis2020 = df2020_concat.loc[filtro_quatis, 'Munic Empr']

#Filtro Barra do Piraí
filtro_barrapirai = df2020_concat['Munic Empr'].str.contains('Barra do Pi', na=False)
df_barrapirai2020 = df2020_concat.loc[filtro_barrapirai, 'Munic Empr']

#Filtro Barra Mansa
filtro_barramansa = df2020_concat['Munic Empr'].str.contains('Barra Mansa', na=False)
df_barramansa2020 = df2020_concat.loc[filtro_barramansa, 'Munic Empr']

#Filtro Pinheiral
filtro_pinheiral= df2020_concat['Munic Empr'].str.contains('Pinheiral', na=False)
df_pinheiral2020 = df2020_concat.loc[filtro_pinheiral, 'Munic Empr']

#Filtro Piraí
filtro_pirai = df2020_concat['Munic Empr'].str.contains('Piraí', na=False)
df_pirai2020 = df2020_concat.loc[filtro_pirai, 'Munic Empr']

#Filtro Rio Claro
filtro_rioclaro = df2020_concat['Munic Empr'].str.contains('Rio Claro', na=False)
df_rioclaro2020 = df2020_concat.loc[filtro_rioclaro, 'Munic Empr']

#Filtro Rio das Flores
filtro_riodasflores = df2020_concat['Munic Empr'].str.contains('Rio das', na=False)
df_riodasflores2020 = df2020_concat.loc[filtro_riodasflores, 'Munic Empr']

#Filtro Valença
filtro_valença = df2020_concat['Munic Empr'].str.contains('Valença', na=False)
df_valença2020 = df2020_concat.loc[filtro_valença, 'Munic Empr']

#Filtro Volta Redonda
filtro_voltaredonda = df2020_concat['Munic Empr'].str.contains('Volta Redonda', na=False)
df_voltaredonda2020 = df2020_concat.loc[filtro_voltaredonda, 'Munic Empr']

# %%
print(f'{df_resende2020.unique()}\n, {df_itatiaia2020.unique()}\n, {df_pr2020.unique()}\n, {df_quatis2020.unique()}\n,{df_barrapirai2020.unique()},{df_barramansa2020.unique()}\n, {df_pinheiral2020.unique()}\n, {df_pirai2020.unique()}\n, {df_rioclaro2020.unique()}\n, {df_riodasflores2020.unique()}\n, {df_valença2020.unique()}\n, {df_voltaredonda2020.unique()}')
# Out:
# ['330420-Resende      ' '314510-Nova Resende ' '315420-Resende Costa']
# , ['330225-Itatiaia     ']
# , ['330411-Porto Real   ']
# , ['330412-Quatis       ']
# ,['330030-Barra do Pira'],['330040-Barra Mansa  ']
# , ['330395-Pinheiral    ']
# , ['330400-Piraí        ' '411940-Piraí do Sul ']
# , ['354390-Rio Claro-Sp ' '330440-Rio Claro-Rj ']
# , ['330452-Rio das Ostra' '354400-Rio das Pedra' '330450-Rio das Flore'
#  '421440-Rio das Antas']
# , ['330610-Valença-Rj   ' '293290-Valença-Ba   ']
# , ['330630-Volta Redonda']

# %%
municipios_desejados = ['330420-Resende      ', '330225-Itatiaia     ', '330411-Porto Real   ', 
'330412-Quatis       ', '330040-Barra Mansa  ', '330030-Barra do Pira', '330395-Pinheiral    ', 
'330400-Piraí        ', '330440-Rio Claro-Rj ', '330450-Rio das Flore','330610-Valença-Rj   ',
'330630-Volta Redonda']
df_fim2020 = df2020_concat[df2020_concat['Munic Empr'].isin(municipios_desejados)]
display(df_fim2020)
# Out:
#        Agente  Causador  Acidente Data Acidente     CBO  \
# 585          Chao - Superficie Ut       2020/01  783225
# 592          Serra- Ferramenta Po       2020/01  514325
# 1052         Motocicleta, Motonet       2020/01  521115
# 1119         Ataque de Ser Vivo p       2020/01  514320
# 1155         Mesa, Carteira, Exce       2020/01  521125
# ...                           ...           ...     ...
# 116404       Agente Infeccioso ou    01/12/2020  414105
# 116415       Agente Infeccioso ou    01/12/2020  322205
# 116482       Equip. Eletrico, Nic    01/12/2020  314210
# 116573       Misturador, Batedeir    01/12/2020  513505
# 116872       Esforco Excessivo, N    01/10/2020  141710
#
#                         CBO.1  CID-10               CID-10.1  \
# 585      783225-Ajudante de M  M624     M62.4 Contratura de
# 592      {ñ class}             S634     S63.4 Rupt Traum Lig
# 1052     521115-Promotor de V  M930     M93.0 Luxacao da Epi
# ...

# %%
df_fim2020['Munic Empr'].unique()
# Out:
# array(['330630-Volta Redonda', '330400-Piraí        ',
#        '330040-Barra Mansa  ', '330610-Valença-Rj   ',
#        '330420-Resende      ', '330030-Barra do Pira',
#        '330225-Itatiaia     ', '330411-Porto Real   ',
#        '330395-Pinheiral    ', '330450-Rio das Flore',
#        '330440-Rio Claro-Rj ', '330412-Quatis       '], dtype=object)

# %%
df_fim2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1368 entries, 585 to 116872
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Agente  Causador  Acidente   1368 non-null   object
#  1   Data Acidente                1368 non-null   object
#  2   CBO                          1368 non-null   int64
#  3   CBO.1                        1368 non-null   object
#  4   CID-10                       1368 non-null   object
#  5   CID-10.1                     1368 non-null   object
#  6   CNAE2.0 Empregador           1368 non-null   int64
#  7   CNAE2.0 Empregador.1         1368 non-null   object
#  8   Emitente CAT                 1368 non-null   object
#  9   Espécie do benefício         1368 non-null   object
#  10  Filiação Segurado            1368 non-null   object
#  11  Indica acidente              1368 non-null   object
#  12  Munic Empr                   1368 non-null   object
# ...

# %% [markdown]
# ### Verificando inconsistencia

# %%
df_fim2020['UF  Munic.  Acidente'].value_counts()
# Out:
# UF  Munic.  Acidente
# Tocantins                1325
# MaranhÃ£o                  25
# RondÃ´nia                   6
# Rondônia                    3
# ParÃ¡                       3
# {ñ class}                   2
# Roraima                     2
# Maranhão                    1
# {Ã± class}                  1
# Name: count, dtype: int64

# %% [markdown]
# ## Montando dataset 2021

# %%
df2021_1 = pd.read_csv('dados\\2021\D.SDA.PDA.005.CAT.202101.csv', encoding= 'ISO-8859-1', sep = ';') 
df2021_2 = pd.read_csv('dados\\2021\D.SDA.PDA.005.CAT.202104.csv', encoding= 'ISO-8859-1', sep = ';') 
df2021_3 = pd.read_csv('dados\\2021\D.SDA.PDA.005.CAT.202107.csv', encoding= 'ISO-8859-1', sep = ';') 
df2021_4 = pd.read_csv('dados\\2021\D.SDA.PDA.005.CAT.202110.csv', encoding= 'ISO-8859-1', sep = ';')

# %% [markdown]
# ### Verificação dos nomes das colunas

# %%
print(f'As colunas em df1 e df2 são iguais: {df2021_1.columns.equals(df2021_2.columns)}')
print(f'As colunas em df2 e df3 são iguais: {df2021_2.columns.equals(df2021_3.columns)}')
print(f'As colunas em df3 e df4 são iguais: {df2021_3.columns.equals(df2021_4.columns)}')
# Out:
# As colunas em df1 e df2 são iguais: True
# As colunas em df2 e df3 são iguais: True
# As colunas em df3 e df4 são iguais: True

# %%
df2021_1.columns
# Out:
# Index(['Agente  Causador  Acidente', 'Data Acidente', 'CBO', 'CID-10',
#        'CNAE2.0 Empregador', 'CNAE2.0 Empregador.1', 'Emitente CAT',
#        'Espécie do benefício', 'Filiação Segurado', 'Indica Óbito Acidente',
#        'Munic Empr', 'Natureza da Lesão', 'Origem de Cadastramento CAT',
#        'Parte Corpo Atingida', 'Sexo', 'Tipo do Acidente',
#        'UF  Munic.  Acidente', 'UF Munic. Empregador', 'Data Acidente.1',
#        'Data Despacho Benefício', 'Data Acidente.2', 'Data Nascimento',
#        'Data Emissão CAT', 'CNPJ/CEI Empregador'],
#       dtype='object')

# %%
df2021_1['Data Acidente']
# Out:
# 0         2021/01
# 1         2021/01
# 2         2021/01
# 3         2021/01
# 4         2021/01
#            ...
# 105235    2021/03
# 105236    2021/03
# 105237    2021/02
# 105238    2021/03
# 105239    2021/01
# Name: Data Acidente, Length: 105240, dtype: object

# %%
df2021_1['Data Acidente.1']
# Out:
# 0         2021/01
# 1         2021/01
# 2         2021/01
# 3         2021/01
# 4         2021/01
#            ...
# 105235    2021/03
# 105236    2021/03
# 105237    2021/02
# 105238    2021/03
# 105239    2021/01
# Name: Data Acidente.1, Length: 105240, dtype: object

# %%
df2021_1['Data Acidente.2']
# Out:
# 0         02/01/2021
# 1         02/01/2021
# 2         03/01/2021
# 3         02/01/2021
# 4         01/01/2021
#              ...
# 105235    11/03/2021
# 105236    26/03/2021
# 105237    16/02/2021
# 105238    03/03/2021
# 105239    27/01/2021
# Name: Data Acidente.2, Length: 105240, dtype: object

# %%
df2021_1['Data Acidente'].equals(df2021_1['Data Acidente.1'])
# Out:
# True

# %% [markdown]
# As colunas 'Data Acidente' e 'Data Acidente.1' são iguais, portanto uma pode ser eliminada.

# %%
df2021_1.drop(['Data Acidente'], axis=1, inplace = True)
df2021_2.drop(['Data Acidente'], axis=1, inplace = True)
df2021_3.drop(['Data Acidente'], axis=1, inplace = True)
df2021_4.drop(['Data Acidente'], axis=1, inplace = True)

# %% [markdown]
# ### Verificação das Datas

# %%
print(f"Período de df1: {df2021_1['Data Acidente.2'].min()} a {df2021_1['Data Acidente.2'].max()}")
print(f"Período de df2: {df2021_2['Data Acidente.2'].min()} a {df2021_2['Data Acidente.2'].max()}")
print(f"Período de df3: {df2021_3['Data Acidente.2'].min()} a {df2021_3['Data Acidente.2'].max()}")
print(f"Período de df4: {df2021_4['Data Acidente.2'].min()} a {df2021_4['Data Acidente.2'].max()}")
# Out:
# Período de df1:  {ñ class} a 31/03/2021
# Período de df2: 01/01/2021 a 31/05/2021
# Período de df3: 01/01/2021 a 31/08/2021
# Período de df4: 01/01/2021 a 31/10/2021

# %% [markdown]
# ### Concatenação do DataSet

# %%
df2021_concat = pd.concat([df2021_1, df2021_2, df2021_3, df2021_4])

# %%
print(f"O dataframe 2021_1 tinha {df2021_1.shape[0]} linhas")
print(f"O dataframe 2021_2 tinha {df2021_2.shape[0]} linhas")
print(f"O dataframe 2021_3 tinha {df2021_3.shape[0]} linhas")
print(f"O dataframe 2021_4 tinha {df2021_4.shape[0]} linhas")
print(f"O dataframe final para 2021 tem {df2021_concat.shape[0]} linhas")
# Out:
# O dataframe 2021_1 tinha 105240 linhas
# O dataframe 2021_2 tinha 118043 linhas
# O dataframe 2021_3 tinha 117304 linhas
# O dataframe 2021_4 tinha 95615 linhas
# O dataframe final para 2021 tem 436202 linhas

# %% [markdown]
# ### Filtragem

# %%
#Filtro Resende
filtro_resende = df2021_concat['Munic Empr'].str.contains('Resende', na=False)
df_resende2021 = df2021_concat.loc[filtro_resende, 'Munic Empr']

#Filtro Itatiaia
filtro_itatiaia = df2021_concat['Munic Empr'].str.contains('Itatiaia', na=False)
df_itatiaia2021 = df2021_concat.loc[filtro_itatiaia, 'Munic Empr']

#Filtro Porto Real
filtro_pr = df2021_concat['Munic Empr'].str.contains('Porto Real', na=False)
df_pr2021 = df2021_concat.loc[filtro_pr, 'Munic Empr']

#Filtra Quatis
filtro_quatis = df2021_concat['Munic Empr'].str.contains('Quatis', na=False)
df_quatis2021 = df2021_concat.loc[filtro_quatis, 'Munic Empr']

#Filtro Barra do Piraí
filtro_barrapirai = df2021_concat['Munic Empr'].str.contains('Barra do Pi', na=False)
df_barrapirai2021 = df2021_concat.loc[filtro_barrapirai, 'Munic Empr']

#Filtro Barra Mansa
filtro_barramansa = df2021_concat['Munic Empr'].str.contains('Barra Mansa', na=False)
df_barramansa2021 = df2021_concat.loc[filtro_barramansa, 'Munic Empr']

#Filtro Pinheiral
filtro_pinheiral= df2021_concat['Munic Empr'].str.contains('Pinheiral', na=False)
df_pinheiral2021 = df2021_concat.loc[filtro_pinheiral, 'Munic Empr']

#Filtro Piraí
filtro_pirai = df2021_concat['Munic Empr'].str.contains('Piraí', na=False)
df_pirai2021 = df2021_concat.loc[filtro_pirai, 'Munic Empr']

#Filtro Rio Claro
filtro_rioclaro = df2021_concat['Munic Empr'].str.contains('Rio Claro', na=False)
df_rioclaro2021 = df2021_concat.loc[filtro_rioclaro, 'Munic Empr']

#Filtro Rio das Flores
filtro_riodasflores = df2021_concat['Munic Empr'].str.contains('Rio das', na=False)
df_riodasflores2021 = df2021_concat.loc[filtro_riodasflores, 'Munic Empr']

#Filtro Valença
filtro_valença = df2021_concat['Munic Empr'].str.contains('Valença', na=False)
df_valença2021 = df2021_concat.loc[filtro_valença, 'Munic Empr']

#Filtro Volta Redonda
filtro_voltaredonda = df2021_concat['Munic Empr'].str.contains('Volta Redonda', na=False)
df_voltaredonda2021 = df2021_concat.loc[filtro_voltaredonda, 'Munic Empr']

# %%
print(f'{df_resende2021.unique()}\n, {df_itatiaia2021.unique()}\n, {df_pr2021.unique()}\n, {df_quatis2021.unique()}\n,{df_barrapirai2021.unique()},{df_barramansa2021.unique()}\n, {df_pinheiral2021.unique()}\n, {df_pirai2021.unique()}\n, {df_rioclaro2021.unique()}\n, {df_riodasflores2021.unique()}\n, {df_valença2021.unique()}\n, {df_voltaredonda2021.unique()}')
# Out:
# ['330420-Resende                           '
#  '314510-Nova Resende                      '
#  '315420-Resende Costa                     ']
# , ['330225-Itatiaia                          ']
# , ['330411-Porto Real                        '
#  '270750-Porto Real do Colégio             ']
# , ['330412-Quatis                            ']
# ,['330030-Barra do Piraí                    '],['330040-Barra Mansa                       ']
# , ['330395-Pinheiral                         ']
# , ['411940-Piraí do Sul                      '
#  '330400-Piraí                             '
#  '330030-Barra do Piraí                    ']
# , ['354390-Rio Claro-Sp                      '
#  '510730-São José do Rio Claro             '
#  '330440-Rio Claro-Rj                      '
#  '311440-Carmo do Rio Claro                ']
# , ['330452-Rio das Ostras                    '
#  '354400-Rio das Pedras                    '
#  '330450-Rio das Flores                    '
# ...

# %%
df_resende2021
# Out:
# 146      330420-Resende
# 282      330420-Resende
# 3833     330420-Resende
# 4309     330420-Resende
# 4470     330420-Resende
#                            ...
# 85552    330420-Resende
# 85726    330420-Resende
# 87159    330420-Resende
# 90445    330420-Resende
# 94988    330420-Resende
# Name: Munic Empr, Length: 326, dtype: object

# %%
df2021_concat.iloc[146]['Munic Empr']
# Out:
# '330420-Resende                           '

# %%
municipios_desejados = ['330420-Resende                           ', '330225-Itatiaia                          ', 
'330411-Porto Real                        ', '330412-Quatis                            ', 
'330030-Barra do Piraí                    ', '330040-Barra Mansa                       ',
'330395-Pinheiral                         ', '330400-Piraí                             ',
'330440-Rio Claro-Rj                      ','330450-Rio das Flores                    ', 
'330610-Valença-Rj                        ','330630-Volta Redonda                     ']
df_fim2021 = df2021_concat[df2021_concat['Munic Empr'].isin(municipios_desejados)]
display(df_fim2021)
# Out:
#                           Agente  Causador  Acidente  \
# 146    Agente Infeccioso ou Parasitario - Inclui Bac
# 282    Piso de Edificio - Superficie Utilizada Para
# 598    Agente Infeccioso ou Parasitario - Inclui Bac
# 615    Caixa, Engradado, Caixote - Embalagem, Recipi
# 900    Masarico - Ferramenta Portatil com Forca Motr
# ...                                              ...
# 94988  {ñ class}
# 95121  Ferramenta Manual sem Forca Motriz, Nic
# 95343  Ferramenta Manual sem Forca Motriz, Nic
# 95442  Ferramenta Manual sem Forca Motriz, Nic
# 95540  Rua e Estrada - Superficie Utilizada para Sus
#
#                                                  CBO  \
# 146    322205-Tec. de Enfermagem
# 282    322205-Tec. de Enfermagem
# 598    513205-Cozinheiro Geral
# 615    521125-Repositor de Mercadorias
# 900    724320-Soldador a  Oxigás
# ...                                              ...
# 94988  314110-Tec. Mecânico
# 95121  322205-Tec. de Enfermagem
# ...

# %%
df_fim2021['Munic Empr'].unique()
# Out:
# array(['330420-Resende                           ',
#        '330630-Volta Redonda                     ',
#        '330040-Barra Mansa                       ',
#        '330610-Valença-Rj                        ',
#        '330412-Quatis                            ',
#        '330225-Itatiaia                          ',
#        '330440-Rio Claro-Rj                      ',
#        '330450-Rio das Flores                    ',
#        '330411-Porto Real                        ',
#        '330400-Piraí                             ',
#        '330030-Barra do Piraí                    ',
#        '330395-Pinheiral                         '], dtype=object)

# %%
df_fim2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1625 entries, 146 to 95540
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Agente  Causador  Acidente   1625 non-null   object
#  1   CBO                          1625 non-null   object
#  2   CID-10                       1625 non-null   object
#  3   CNAE2.0 Empregador           1625 non-null   int64
#  4   CNAE2.0 Empregador.1         1625 non-null   object
#  5   Emitente CAT                 1625 non-null   object
#  6   Espécie do benefício         1625 non-null   object
#  7   Filiação Segurado            1625 non-null   object
#  8   Indica Óbito Acidente        1625 non-null   object
#  9   Munic Empr                   1625 non-null   object
#  10  Natureza da Lesão            1625 non-null   object
#  11  Origem de Cadastramento CAT  1625 non-null   object
#  12  Parte Corpo Atingida         1625 non-null   object
# ...

# %% [markdown]
# ### Verificando inconsistencia

# %%
df_fim2021['UF  Munic.  Acidente'].value_counts()
# Out:
# UF  Munic.  Acidente
# Tocantins           1604
# Maranhão              14
# Rondônia               7
# Name: count, dtype: int64

# %% [markdown]
# ## Montando dataset 2022

# %%
df2022_1 = pd.read_csv('dados\\2022\D.SDA.PDA.005.CAT.202201.csv', encoding= 'ISO-8859-1', sep = ';') 
df2022_2 = pd.read_csv('dados\\2022\D.SDA.PDA.005.CAT.202204.csv', encoding= 'ISO-8859-1', sep = ';') 
df2022_3 = pd.read_csv('dados\\2022\D.SDA.PDA.005.CAT.202207.csv', encoding= 'ISO-8859-1', sep = ';') 
df2022_4 = pd.read_csv('dados\\2022\D.SDA.PDA.005.CAT.202208.csv', encoding= 'ISO-8859-1', sep = ';') 
df2022_5 = pd.read_csv('dados\\2022\D.SDA.PDA.005.CAT.202209.csv', encoding= 'ISO-8859-1', sep = ';') 
df2022_6 = pd.read_csv('dados\\2022\D.SDA.PDA.005.CAT.202210.csv', encoding= 'ISO-8859-1', sep = ';') 
df2022_7 = pd.read_csv('dados\\2022\D.SDA.PDA.005.CAT.202211.csv', encoding= 'ISO-8859-1', sep = ';') 
df2022_8 = pd.read_csv('dados\\2022\D.SDA.PDA.005.CAT.202212.csv', encoding= 'ISO-8859-1', sep = ';')

# %% [markdown]
# ### Verificação dos nomes das colunas

# %%
print(f'As colunas em df1 e df2 são iguais: {df2022_1.columns.equals(df2022_2.columns)}')
print(f'As colunas em df2 e df3 são iguais: {df2022_2.columns.equals(df2022_3.columns)}')
print(f'As colunas em df3 e df4 são iguais: {df2022_3.columns.equals(df2022_4.columns)}')
print(f'As colunas em df4 e df5 são iguais: {df2022_4.columns.equals(df2022_5.columns)}')
print(f'As colunas em df5 e df6 são iguais: {df2022_5.columns.equals(df2022_6.columns)}')
print(f'As colunas em df6 e df7 são iguais: {df2022_6.columns.equals(df2022_7.columns)}')
print(f'As colunas em df7 e df8 são iguais: {df2022_7.columns.equals(df2022_8.columns)}')
# Out:
# As colunas em df1 e df2 são iguais: True
# As colunas em df2 e df3 são iguais: True
# As colunas em df3 e df4 são iguais: True
# As colunas em df4 e df5 são iguais: True
# As colunas em df5 e df6 são iguais: True
# As colunas em df6 e df7 são iguais: True
# As colunas em df7 e df8 são iguais: True

# %%
df2022_1.columns
# Out:
# Index(['Agente  Causador  Acidente', 'Data Acidente', 'CBO', 'CID-10',
#        'CNAE2.0 Empregador', 'CNAE2.0 Empregador.1', 'Emitente CAT',
#        'Espécie do benefício', 'Filiação Segurado', 'Indica Óbito Acidente',
#        'Munic Empr', 'Natureza da Lesão', 'Origem de Cadastramento CAT',
#        'Parte Corpo Atingida', 'Sexo', 'Tipo do Acidente',
#        'UF  Munic.  Acidente', 'UF Munic. Empregador', 'Data Acidente.1',
#        'Data Despacho Benefício', 'Data Acidente.2', 'Data Nascimento',
#        'Data Emissão CAT', 'CNPJ/CEI Empregador'],
#       dtype='object')

# %% [markdown]
# ### Verificação das Datas

# %%
print(f"Período de df1: {df2022_1['Data Acidente.2'].min()} a {df2022_1['Data Acidente.2'].max()}")
print(f"Período de df2: {df2022_2['Data Acidente.2'].min()} a {df2022_2['Data Acidente.2'].max()}")
print(f"Período de df3: {df2022_3['Data Acidente.2'].min()} a {df2022_3['Data Acidente.2'].max()}")
print(f"Período de df4: {df2022_4['Data Acidente.2'].min()} a {df2022_4['Data Acidente.2'].max()}")
print(f"Período de df1: {df2022_5['Data Acidente.2'].min()} a {df2022_5['Data Acidente.2'].max()}")
print(f"Período de df2: {df2022_6['Data Acidente.2'].min()} a {df2022_6['Data Acidente.2'].max()}")
print(f"Período de df3: {df2022_7['Data Acidente.2'].min()} a {df2022_7['Data Acidente.2'].max()}")
print(f"Período de df4: {df2022_8['Data Acidente.2'].min()} a {df2022_8['Data Acidente.2'].max()}")
# Out:
# Período de df1: 01/01/2022 a 31/05/2022
# Período de df2: 01/01/2022 a 31/05/2022
# Período de df3: 01/01/2022 a 31/10/2022
# Período de df4: 01/01/2022 a 31/10/2022
# Período de df1: 01/01/2022 a 31/10/2022
# Período de df2: 01/01/2022 a 31/10/2022
# Período de df3: 01/02/2022 a 31/10/2022
# Período de df4: 01/01/2022 a 31/10/2022

# %%
print(f"Período de df1: {df2022_1['Data Emissão CAT'].min()} a {df2022_8['Data Emissão CAT'].max()}")
# Out:
# Período de df1: 00/00/0000 a 31/12/2022

# %% [markdown]
# ### Concatenação do DataSet

# %%
df2022_concat = pd.concat([df2022_1, df2022_2, df2022_3, df2022_4, df2022_5, df2022_6, df2022_7, df2022_8])

# %%
print(f"O dataframe final para 2022 tem {df2022_concat.shape[0]} linhas")
# Out:
# O dataframe final para 2022 tem 665369 linhas

# %% [markdown]
# ### Filtragem

# %%
municipios_desejados = ['330420-Resende                           ', '330225-Itatiaia                          ', 
'330411-Porto Real                        ', '330412-Quatis                            ', 
'330030-Barra do Piraí                    ', '330040-Barra Mansa                       ',
'330395-Pinheiral                         ', '330400-Piraí                             ',
'330440-Rio Claro-Rj                      ','330450-Rio das Flores                    ', 
'330610-Valença-Rj                        ','330630-Volta Redonda                     ']
df_fim2022 = df2022_concat[df2022_concat['Munic Empr'].isin(municipios_desejados)]
display(df_fim2022)
# Out:
#                           Agente  Causador  Acidente Data Acidente  \
# 1320   Empilhadeira                                        2022/02
# 1942   Aprision. Em, Sobre ou Entre Objetos Em             2022/02
# 2133   Atrito ou Abrasao, Nic                              2022/01
# 2134   Ruido                                               2022/02
# 2406   Aprision. Em, Sob ou Entre, Nic                     2022/03
# ...                                              ...           ...
# 24719  Ferramenta Manual sem Forca Motriz, Nic             2022/12
# 25182  {ñ class}                                           2022/11
# 25231  {ñ class}                                           2022/11
# 25361  Escada Permanente Cujos Degraus Permitem Apoi       2022/12
# 25386  Escada Permanente Cujos Degraus Permitem Apoi       2022/12
#
#                                                  CBO  \
# 1320   141205-Gerente de Prod. e Oper.
# 1942   784205-Alimentador de Linha de Prod.
# 2133   {ñ class}
# ...

# %%
df_fim2022['Munic Empr'].unique()
# Out:
# array(['330610-Valença-Rj                        ',
#        '330040-Barra Mansa                       ',
#        '330630-Volta Redonda                     ',
#        '330420-Resende                           ',
#        '330030-Barra do Piraí                    ',
#        '330400-Piraí                             ',
#        '330450-Rio das Flores                    ',
#        '330412-Quatis                            ',
#        '330440-Rio Claro-Rj                      ',
#        '330225-Itatiaia                          ',
#        '330395-Pinheiral                         ',
#        '330411-Porto Real                        '], dtype=object)

# %%
df_fim2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2072 entries, 1320 to 25386
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Agente  Causador  Acidente   2072 non-null   object
#  1   Data Acidente                2072 non-null   object
#  2   CBO                          2072 non-null   object
#  3   CID-10                       2072 non-null   object
#  4   CNAE2.0 Empregador           2072 non-null   int64
#  5   CNAE2.0 Empregador.1         2072 non-null   object
#  6   Emitente CAT                 2072 non-null   object
#  7   Espécie do benefício         2072 non-null   object
#  8   Filiação Segurado            2072 non-null   object
#  9   Indica Óbito Acidente        2072 non-null   object
#  10  Munic Empr                   2072 non-null   object
#  11  Natureza da Lesão            2072 non-null   object
#  12  Origem de Cadastramento CAT  2072 non-null   object
# ...

# %% [markdown]
# ### Verificando inconsistencia

# %%
df_fim2022['UF  Munic.  Acidente'].value_counts()
# Out:
# UF  Munic.  Acidente
# Tocantins           1987
# Maranhão              31
# {ñ class}             31
# Rondônia               9
# Roraima                7
# Pernambuco             4
# Pará                   3
# Name: count, dtype: int64

# %% [markdown]
# ## Montando dataset 2023

# %%
df2023_1 = pd.read_csv('dados\\2023\D.SDA.PDA.005.CAT.202301.csv', encoding= 'ISO-8859-1', sep = ';') 
df2023_2 = pd.read_csv('dados\\2023\D.SDA.PDA.005.CAT.202302.csv', encoding= 'ISO-8859-1', sep = ';')
df2023_3 = pd.read_csv('dados\\2023\D.SDA.PDA.005.CAT.202303.csv', encoding= 'ISO-8859-1', sep = ';')
df2023_4 = pd.read_csv('dados\\2023\D.SDA.PDA.005.CAT.202304.csv', encoding= 'ISO-8859-1', sep = ';')
df2023_5 = pd.read_csv('dados\\2023\D.SDA.PDA.005.CAT.202305.csv', encoding= 'ISO-8859-1', sep = ';')
df2023_6 = pd.read_csv('dados\\2023\D.SDA.PDA.005.CAT.202306.csv', encoding= 'ISO-8859-1', sep = ';')
df2023_7 = pd.read_csv('dados\\2023\D.SDA.PDA.005.CAT.202307.csv', encoding= 'ISO-8859-1', sep = ';')
df2023_8 = pd.read_csv('dados\\2023\D.SDA.PDA.005.CAT.202308.csv', encoding= 'ISO-8859-1', sep = ';')
df2023_9 = pd.read_csv('dados\\2023\D.SDA.PDA.005.CAT.202309.csv', encoding= 'ISO-8859-1', sep = ';')
df2023_10 = pd.read_csv('dados\\2023\D.SDA.PDA.005.CAT.202310.csv', encoding= 'ISO-8859-1', sep = ';')
df2023_11 = pd.read_csv('dados\\2023\D.SDA.PDA.005.CAT.202311.csv', encoding= 'ISO-8859-1', sep = ';')
df2023_12 = pd.read_csv('dados\\2023\D.SDA.PDA.005.CAT.202312.csv', encoding= 'ISO-8859-1', sep = ';')

# %%
print(f'As colunas em df1 e df2 são iguais: {df2023_1.columns.equals(df2023_2.columns)}')
print(f'As colunas em df2 e df3 são iguais: {df2023_2.columns.equals(df2023_3.columns)}')
print(f'As colunas em df3 e df4 são iguais: {df2023_3.columns.equals(df2023_4.columns)}')
print(f'As colunas em df4 e df5 são iguais: {df2023_4.columns.equals(df2023_5.columns)}')
print(f'As colunas em df5 e df6 são iguais: {df2023_5.columns.equals(df2023_6.columns)}')
print(f'As colunas em df6 e df7 são iguais: {df2023_6.columns.equals(df2023_7.columns)}')
print(f'As colunas em df7 e df8 são iguais: {df2023_7.columns.equals(df2023_8.columns)}')
print(f'As colunas em df8 e df9 são iguais: {df2023_8.columns.equals(df2023_9.columns)}')
print(f'As colunas em df9 e df10 são iguais: {df2023_9.columns.equals(df2023_10.columns)}')
print(f'As colunas em df10 e df11 são iguais: {df2023_10.columns.equals(df2023_11.columns)}')
print(f'As colunas em df11 e df12 são iguais: {df2023_11.columns.equals(df2023_12.columns)}')
# Out:
# As colunas em df1 e df2 são iguais: True
# As colunas em df2 e df3 são iguais: True
# As colunas em df3 e df4 são iguais: True
# As colunas em df4 e df5 são iguais: True
# As colunas em df5 e df6 são iguais: False
# As colunas em df6 e df7 são iguais: True
# As colunas em df7 e df8 são iguais: True
# As colunas em df8 e df9 são iguais: True
# As colunas em df9 e df10 são iguais: True
# As colunas em df10 e df11 são iguais: False
# As colunas em df11 e df12 são iguais: True

# %%
df2023_5.columns
# Out:
# Index(['Agente  Causador  Acidente', 'Data Acidente', 'CBO', 'CID-10',
#        'CNAE2.0 Empregador', 'CNAE2.0 Empregador.1', 'Emitente CAT',
#        'Espécie do benefício', 'Filiação Segurado', 'Indica Óbito Acidente',
#        'Munic Empr', 'Natureza da Lesão', 'Origem de Cadastramento CAT',
#        'Parte Corpo Atingida', 'Sexo', 'Tipo do Acidente',
#        'UF  Munic.  Acidente', 'UF Munic. Empregador', 'Data Acidente.1',
#        'Data Despacho Benefício', 'Data Acidente.2', 'Data Nascimento',
#        'Data Emissão CAT', 'CNPJ/CEI Empregador'],
#       dtype='object')

# %%
df2023_5['Data Acidente']
# Out:
# 0        2023/04
# 1        2023/03
# 2        2023/04
# 3        2023/03
# 4        2023/04
#           ...
# 57494    2023/05
# 57495    2023/05
# 57496    2023/05
# 57497    2023/05
# 57498    2023/03
# Name: Data Acidente, Length: 57499, dtype: object

# %%
df2023_5['Data Acidente.1']
# Out:
# 0        2023/04
# 1        2023/03
# 2        2023/04
# 3        2023/03
# 4        2023/04
#           ...
# 57494    2023/05
# 57495    2023/05
# 57496    2023/05
# 57497    2023/05
# 57498    2023/03
# Name: Data Acidente.1, Length: 57499, dtype: object

# %%
df2023_5['Data Acidente.2']
# Out:
# 0        24/04/2023
# 1        27/03/2023
# 2        30/04/2023
# 3        31/03/2023
# 4        15/04/2023
#             ...
# 57494    02/05/2023
# 57495    16/05/2023
# 57496    30/05/2023
# 57497    11/05/2023
# 57498    17/03/2023
# Name: Data Acidente.2, Length: 57499, dtype: object

# %%
df2023_1.drop(['Data Acidente'], axis=1, inplace = True)
df2023_2.drop(['Data Acidente'], axis=1, inplace = True)
df2023_3.drop(['Data Acidente'], axis=1, inplace = True)
df2023_4.drop(['Data Acidente'], axis=1, inplace = True)
df2023_5.drop(['Data Acidente'], axis=1, inplace = True)

df2023_1.drop(['Data Acidente.1'], axis=1, inplace = True)
df2023_2.drop(['Data Acidente.1'], axis=1, inplace = True)
df2023_3.drop(['Data Acidente.1'], axis=1, inplace = True)
df2023_4.drop(['Data Acidente.1'], axis=1, inplace = True)
df2023_5.drop(['Data Acidente.1'], axis=1, inplace = True)

# %%
df2023_1.rename(columns={'Data Acidente.2': 'Data Acidente.1'}, inplace = True)
df2023_2.rename(columns={'Data Acidente.2': 'Data Acidente.1'}, inplace = True)
df2023_3.rename(columns={'Data Acidente.2': 'Data Acidente.1'}, inplace = True)
df2023_4.rename(columns={'Data Acidente.2': 'Data Acidente.1'}, inplace = True)
df2023_5.rename(columns={'Data Acidente.2': 'Data Acidente.1'}, inplace = True)

# %%
df2023_6.columns
# Out:
# Index(['Agente  Causador  Acidente', 'Data Acidente', 'CBO', 'CBO.1', 'CID-10',
#        'CID-10.1', 'CNAE2.0 Empregador', 'CNAE2.0 Empregador.1',
#        'Emitente CAT', 'Espécie do benefício', 'Filiação Segurado',
#        'Indica Óbito Acidente', 'Munic Empr', 'Natureza da Lesão',
#        'Origem de Cadastramento CAT', 'Parte Corpo Atingida', 'Sexo',
#        'Tipo do Acidente', 'UF  Munic.  Acidente', 'UF Munic. Empregador',
#        'Data  Afastamento', 'Data Acidente.1', 'Data Nascimento',
#        'Data Acidente.2'],
#       dtype='object')

# %%
df2023_6['Data Acidente']
# Out:
# 0        31/05/2023
# 1        30/05/2023
# 2        31/05/2023
# 3        30/05/2023
# 4        30/05/2023
#             ...
# 52826    30/06/2023
# 52827    26/06/2023
# 52828    21/06/2023
# 52829    27/06/2023
# 52830    04/06/2023
# Name: Data Acidente, Length: 52831, dtype: object

# %%
df2023_6['Data Acidente.1']
# Out:
# 0        31/05/2023
# 1        30/05/2023
# 2        31/05/2023
# 3        30/05/2023
# 4        30/05/2023
#             ...
# 52826    30/06/2023
# 52827    26/06/2023
# 52828    21/06/2023
# 52829    27/06/2023
# 52830    04/06/2023
# Name: Data Acidente.1, Length: 52831, dtype: object

# %%
df2023_6['Data Acidente.2']
# Out:
# 0        31/05/2023
# 1        30/05/2023
# 2        31/05/2023
# 3        30/05/2023
# 4        30/05/2023
#             ...
# 52826    30/06/2023
# 52827    26/06/2023
# 52828    21/06/2023
# 52829    27/06/2023
# 52830    04/06/2023
# Name: Data Acidente.2, Length: 52831, dtype: object

# %%
df2023_6.drop(['Data Acidente'], axis=1, inplace = True)
df2023_7.drop(['Data Acidente'], axis=1, inplace = True)
df2023_8.drop(['Data Acidente'], axis=1, inplace = True)
df2023_9.drop(['Data Acidente'], axis=1, inplace = True)
df2023_10.drop(['Data Acidente'], axis=1, inplace = True)

df2023_6.drop(['Data Acidente.2'], axis=1, inplace = True)
df2023_7.drop(['Data Acidente.2'], axis=1, inplace = True)
df2023_8.drop(['Data Acidente.2'], axis=1, inplace = True)
df2023_9.drop(['Data Acidente.2'], axis=1, inplace = True)
df2023_10.drop(['Data Acidente.2'], axis=1, inplace = True)

# %%
df2023_11.columns
# Out:
# Index(['Agente  Causador  Acidente', 'Data Acidente', 'CBO', 'CBO.1', 'CID-10',
#        'CID-10.1', 'CNAE2.0 Empregador', 'CNAE2.0 Empregador.1',
#        'Emitente CAT', 'Espécie do benefício', 'Filiação Segurado',
#        'Indica Óbito Acidente', 'Munic Empr', 'Natureza da Lesão',
#        'Origem de Cadastramento CAT', 'Parte Corpo Atingida', 'Sexo',
#        'Tipo do Acidente', 'UF  Munic.  Acidente', 'UF Munic. Empregador',
#        'Data  Afastamento', 'Data Despacho Benefício', 'Data Acidente.1',
#        'Data Nascimento', 'Data Emissão CAT', 'Tipo de Empregador',
#        'CNPJ/CEI Empregador'],
#       dtype='object')

# %%
df2023_11['Data Acidente.1']
# Out:
# 0        14/11/2023
# 1        16/10/2023
# 2        13/11/2023
# 3        14/11/2023
# 4        12/11/2023
#             ...
# 49947    11/10/2023
# 49948    07/10/2023
# 49949    30/10/2023
# 49950    07/11/2023
# 49951    31/08/2023
# Name: Data Acidente.1, Length: 49952, dtype: object

# %%
df2023_11['Data Acidente']
# Out:
# 0        14/11/2023
# 1        16/10/2023
# 2        13/11/2023
# 3        14/11/2023
# 4        12/11/2023
#             ...
# 49947    11/10/2023
# 49948    07/10/2023
# 49949    30/10/2023
# 49950    07/11/2023
# 49951    31/08/2023
# Name: Data Acidente, Length: 49952, dtype: object

# %%
df2023_11.drop(['Data Acidente'], axis=1, inplace = True)
df2023_12.drop(['Data Acidente'], axis=1, inplace = True)

# %% [markdown]
# ### Concatenação do dataset 2023

# %%
df2023_concat = pd.concat([df2023_1, df2023_2, df2023_3, df2023_4, df2023_5, df2023_6, df2023_7, df2023_8, df2023_9, df2023_10, df2023_11, df2023_12])

# %%
print(f"O dataframe final para 2023 tem {df2023_concat.shape[0]} linhas")
# Out:
# O dataframe final para 2023 tem 603825 linhas

# %% [markdown]
# ### Filtragem

# %%
municipios_desejados = ['330420-Resende                           ', '330225-Itatiaia                          ', 
'330411-Porto Real                        ', '330412-Quatis                            ', 
'330030-Barra do Piraí                    ', '330040-Barra Mansa                       ',
'330395-Pinheiral                         ', '330400-Piraí                             ',
'330440-Rio Claro-Rj                      ','330450-Rio das Flores                    ', 
'330610-Valença-Rj                        ','330630-Volta Redonda                     ']
df_fim2023 = df2023_concat[df2023_concat['Munic Empr'].isin(municipios_desejados)]
display(df_fim2023)
# Out:
#                           Agente  Causador  Acidente  \
# 57     Esforco Excessivo ao Empurrar ou Puxar Objeto
# 378    Atrito ou Abrasao por Manusear Objeto
# 675    Vidraria, Fibra de Vidro, Lamina, Etc., Excet
# 755    Impacto Sofrido por Pes., Nic
# 846    {ñ class}
# ...                                              ...
# 56531  Impacto de Pes. Contra Objeto em Movimento
# 56705  Queda de Pes. em Mesmo Nivel, Nic
# 56834  Piso de Edificio - Superficie Utilizada Para
# 57000  Aprision. Em, Sobre ou Entre Desabamento
# 57069  Rua e Estrada - Superficie Utilizada para Sus
#
#                                                  CBO  \
# 57     521110-Vendedor de Comércio Varejista
# 378    {ñ class}
# 675    {ñ class}
# 755    782310-Motorista de Furgão ou Veículo Similar
# 846    322205-Tec. de Enfermagem
# ...                                              ...
# 56531  514225-Trab. de Serv. de Manut. de Edifícios
# 56705  251510-Psicólogo Clínico
# ...

# %%
df_fim2023['Munic Empr'].unique()
# Out:
# array(['330630-Volta Redonda                     ',
#        '330040-Barra Mansa                       ',
#        '330420-Resende                           ',
#        '330400-Piraí                             ',
#        '330411-Porto Real                        ',
#        '330030-Barra do Piraí                    ',
#        '330225-Itatiaia                          ',
#        '330610-Valença-Rj                        ',
#        '330450-Rio das Flores                    ',
#        '330412-Quatis                            ',
#        '330395-Pinheiral                         ',
#        '330440-Rio Claro-Rj                      '], dtype=object)

# %%
df_fim2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 718 entries, 57 to 57069
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Agente  Causador  Acidente   718 non-null    object
#  1   CBO                          718 non-null    object
#  2   CID-10                       718 non-null    object
#  3   CNAE2.0 Empregador           718 non-null    int64
#  4   CNAE2.0 Empregador.1         718 non-null    object
#  5   Emitente CAT                 718 non-null    object
#  6   Espécie do benefício         718 non-null    object
#  7   Filiação Segurado            718 non-null    object
#  8   Indica Óbito Acidente        718 non-null    object
#  9   Munic Empr                   718 non-null    object
#  10  Natureza da Lesão            718 non-null    object
#  11  Origem de Cadastramento CAT  718 non-null    object
#  12  Parte Corpo Atingida         718 non-null    object
# ...

# %% [markdown]
# ### Verificando inconsistencia

# %%
df_fim2023['UF  Munic.  Acidente'].value_counts()
# Out:
# UF  Munic.  Acidente
# Tocantins           718
# Name: count, dtype: int64

# %% [markdown]
# ## Montando dataset 2024

# %%
df2024_1 = pd.read_csv('dados\\2024\D.SDA.PDA.005.CAT.202401.csv', encoding= 'ISO-8859-1', sep = ';') 
df2024_2 = pd.read_csv('dados\\2024\D.SDA.PDA.005.CAT.202402.csv', encoding= 'ISO-8859-1', sep = ';')
df2024_3 = pd.read_csv('dados\\2024\D.SDA.PDA.005.CAT.202403.csv', encoding= 'ISO-8859-1', sep = ';')
df2024_4 = pd.read_csv('dados\\2024\D.SDA.PDA.005.CAT.202404.csv', encoding= 'ISO-8859-1', sep = ';')
df2024_5 = pd.read_csv('dados\\2024\D.SDA.PDA.005.CAT.202405.csv', encoding= 'ISO-8859-1', sep = ';')
df2024_6 = pd.read_csv('dados\\2024\D.SDA.PDA.005.CAT.202406.csv', encoding= 'ISO-8859-1', sep = ';')
df2024_7 = pd.read_csv('dados\\2024\D.SDA.PDA.005.CAT.202407.csv', encoding= 'ISO-8859-1', sep = ';')
df2024_8 = pd.read_csv('dados\\2024\D.SDA.PDA.005.CAT.202408.csv', encoding= 'ISO-8859-1', sep = ';')

# %%
print(f'As colunas em df1 e df2 são iguais: {df2024_1.columns.equals(df2024_2.columns)}')
print(f'As colunas em df2 e df3 são iguais: {df2024_2.columns.equals(df2024_3.columns)}')
print(f'As colunas em df3 e df4 são iguais: {df2024_3.columns.equals(df2024_4.columns)}')
print(f'As colunas em df4 e df5 são iguais: {df2024_4.columns.equals(df2024_5.columns)}')
print(f'As colunas em df5 e df6 são iguais: {df2024_5.columns.equals(df2024_6.columns)}')
print(f'As colunas em df6 e df7 são iguais: {df2024_6.columns.equals(df2024_7.columns)}')
print(f'As colunas em df7 e df8 são iguais: {df2024_7.columns.equals(df2024_8.columns)}')
# Out:
# As colunas em df1 e df2 são iguais: True
# As colunas em df2 e df3 são iguais: True
# As colunas em df3 e df4 são iguais: True
# As colunas em df4 e df5 são iguais: True
# As colunas em df5 e df6 são iguais: True
# As colunas em df6 e df7 são iguais: True
# As colunas em df7 e df8 são iguais: True

# %%
df2024_1.columns
# Out:
# Index(['Agente  Causador  Acidente', 'Data Acidente', 'CBO', 'CBO.1', 'CID-10',
#        'CID-10.1', 'CNAE2.0 Empregador', 'CNAE2.0 Empregador.1',
#        'Emitente CAT', 'Espécie do benefício', 'Filiação Segurado',
#        'Indica Óbito Acidente', 'Munic Empr', 'Natureza da Lesão',
#        'Origem de Cadastramento CAT', 'Parte Corpo Atingida', 'Sexo',
#        'Tipo do Acidente', 'UF  Munic.  Acidente', 'UF Munic. Empregador',
#        'Data  Afastamento', 'Data Despacho Benefício', 'Data Acidente.1',
#        'Data Nascimento', 'Data Emissão CAT', 'Tipo de Empregador',
#        'CNPJ/CEI Empregador'],
#       dtype='object')

# %% [markdown]
# ### Concatenação

# %%
df2024_concat = pd.concat([df2024_1, df2024_2, df2024_3, df2024_4, df2024_5, df2024_6, df2024_7, df2024_8])

# %%
print(f"O dataframe final para 2024 tem {df2024_concat.shape[0]} linhas")
# Out:
# O dataframe final para 2024 tem 481314 linhas

# %% [markdown]
# ### Filtragem

# %%
#Filtro Resende
filtro_resende = df2024_concat['Munic Empr'].str.contains('Resende', na=False)
df_resende2024 = df2024_concat.loc[filtro_resende, 'Munic Empr']

#Filtro Itatiaia
filtro_itatiaia = df2024_concat['Munic Empr'].str.contains('Itatiaia', na=False)
df_itatiaia2024 = df2024_concat.loc[filtro_itatiaia, 'Munic Empr']

#Filtro Porto Real
filtro_pr = df2024_concat['Munic Empr'].str.contains('Porto Real', na=False)
df_pr2024 = df2024_concat.loc[filtro_pr, 'Munic Empr']

#Filtra Quatis
filtro_quatis = df2024_concat['Munic Empr'].str.contains('Quatis', na=False)
df_quatis2024 = df2024_concat.loc[filtro_quatis, 'Munic Empr']

#Filtro Barra do Piraí
filtro_barrapirai = df2024_concat['Munic Empr'].str.contains('Barra do Pi', na=False)
df_barrapirai2024 = df2024_concat.loc[filtro_barrapirai, 'Munic Empr']

#Filtro Barra Mansa
filtro_barramansa = df2024_concat['Munic Empr'].str.contains('Barra Mansa', na=False)
df_barramansa2024 = df2024_concat.loc[filtro_barramansa, 'Munic Empr']

#Filtro Pinheiral
filtro_pinheiral= df2024_concat['Munic Empr'].str.contains('Pinheiral', na=False)
df_pinheiral2024 = df2024_concat.loc[filtro_pinheiral, 'Munic Empr']

#Filtro Piraí
filtro_pirai = df2024_concat['Munic Empr'].str.contains('Piraí', na=False)
df_pirai2024 = df2024_concat.loc[filtro_pirai, 'Munic Empr']

#Filtro Rio Claro
filtro_rioclaro = df2024_concat['Munic Empr'].str.contains('Rio Claro', na=False)
df_rioclaro2024 = df2024_concat.loc[filtro_rioclaro, 'Munic Empr']

#Filtro Rio das Flores
filtro_riodasflores = df2024_concat['Munic Empr'].str.contains('Rio das', na=False)
df_riodasflores2024 = df2024_concat.loc[filtro_riodasflores, 'Munic Empr']

#Filtro Valença
filtro_valença = df2024_concat['Munic Empr'].str.contains('Valença', na=False)
df_valença2024 = df2024_concat.loc[filtro_valença, 'Munic Empr']

#Filtro Volta Redonda
filtro_voltaredonda = df2024_concat['Munic Empr'].str.contains('Volta Redonda', na=False)
df_voltaredonda2024 = df2024_concat.loc[filtro_voltaredonda, 'Munic Empr']

# %%
print(f'{df_resende2024.unique()}\n, {df_itatiaia2024.unique()}\n, {df_pr2024.unique()}\n, {df_quatis2024.unique()}\n,{df_barrapirai2024.unique()},{df_barramansa2024.unique()}\n, {df_pinheiral2024.unique()}\n, {df_pirai2024.unique()}\n, {df_rioclaro2024.unique()}\n, {df_riodasflores2024.unique()}\n, {df_valença2024.unique()}\n, {df_voltaredonda2024.unique()}')
# Out:
# ['330420-Resende      ' '314510-Nova Resende ' '315420-Resende Costa']
# , ['330225-Itatiaia     ']
# , ['330411-Porto Real   ']
# , ['330412-Quatis       ']
# ,['330030-Barra do Pira'],['330040-Barra Mansa  ']
# , ['330395-Pinheiral    ']
# , ['411940-Piraí do Sul ' '330400-Piraí        ']
# , ['354390-Rio Claro-Sp ' '330440-Rio Claro-Rj ']
# , ['354400-Rio das Pedra' '330452-Rio das Ostra' '330450-Rio das Flore'
#  '421440-Rio das Antas']
# , ['293290-Valença-Ba   ' '330610-Valença-Rj   ' '221130-Valença do Pi']
# , ['330630-Volta Redonda']

# %%
df_resende2024
# Out:
# 1456     330420-Resende
# 5146     330420-Resende
# 5952     330420-Resende
# 9315     330420-Resende
# 9561     330420-Resende
#                  ...
# 29290    330420-Resende
# 32749    330420-Resende
# 32967    330420-Resende
# 33785    330420-Resende
# 34942    330420-Resende
# Name: Munic Empr, Length: 298, dtype: object

# %%
df2024_concat.iloc[1456]['Munic Empr']
# Out:
# '330420-Resende      '

# %%
municipios_desejados = ['330420-Resende      ', '330225-Itatiaia     ', '330411-Porto Real   ', 
'330412-Quatis       ', '330030-Barra do Pira', '330040-Barra Mansa  ',
'330395-Pinheiral    ', '330400-Piraí        ', '330440-Rio Claro-Rj ',
'330450-Rio das Flore', '330610-Valença-Rj   ', '330630-Volta Redonda']
df_fim2024 = df2024_concat[df2024_concat['Munic Empr'].isin(municipios_desejados)]
display(df_fim2024)
# Out:
#       Agente  Causador  Acidente Data Acidente     CBO                 CBO.1  \
# 149         Maquina, Nic            02/01/2024  784205  784205-Alimentador d
# 186         Faca, Facao- Ferrame    02/01/2024  521125  521125-Repositor de
# 568         Impacto Sofrido por     02/01/2024  322205  322205-Tec. de Enfer
# 656         Veiculo Rodoviario M    03/01/2024  322205  322205-Tec. de Enfer
# 1356        Queda de Pes. com Di    03/01/2024  519110  519110-Motociclista
# ...                          ...           ...     ...                   ...
# 34304       Caixa, Engradado, Ca    16/08/2024  414125  {ñ class}
# 34512       Tubo, Manilha - Cera    15/08/2024  784205  784205-Alimentador d
# 34733       Piso de Veiculo - Su    16/08/2024  414105  414105-Almoxarife
# 34942       Rua e Estrada - Supe    17/08/2024  519110  519110-Motociclista
# 35916       Escada Permanente Cu    18/08/2024  414125  {ñ class}
#
# ...

# %%
df_fim2024['Munic Empr'].unique()
# Out:
# array(['330040-Barra Mansa  ', '330030-Barra do Pira',
#        '330630-Volta Redonda', '330420-Resende      ',
#        '330411-Porto Real   ', '330225-Itatiaia     ',
#        '330395-Pinheiral    ', '330610-Valença-Rj   ',
#        '330400-Piraí        ', '330412-Quatis       ',
#        '330450-Rio das Flore', '330440-Rio Claro-Rj '], dtype=object)

# %%
df_fim2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1734 entries, 149 to 35916
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Agente  Causador  Acidente   1734 non-null   object
#  1   Data Acidente                1734 non-null   object
#  2   CBO                          1734 non-null   int64
#  3   CBO.1                        1734 non-null   object
#  4   CID-10                       1734 non-null   object
#  5   CID-10.1                     1734 non-null   object
#  6   CNAE2.0 Empregador           1734 non-null   int64
#  7   CNAE2.0 Empregador.1         1734 non-null   object
#  8   Emitente CAT                 1734 non-null   object
#  9   Espécie do benefício         1734 non-null   object
#  10  Filiação Segurado            1734 non-null   object
#  11  Indica Óbito Acidente        1734 non-null   object
#  12  Munic Empr                   1734 non-null   object
# ...

# %% [markdown]
# ### Verificando

# %%
df_fim2021['UF  Munic.  Acidente'].value_counts()
# Out:
# UF  Munic.  Acidente
# Tocantins           1604
# Maranhão              14
# Rondônia               7
# Name: count, dtype: int64

# %% [markdown]
# ## Montando Dataset final

# %% [markdown]
# ### Verificação da quantidade das colunas

# %%
print(f'O dataset 2018 tem formato: {df_fim2018.shape}')
print(f'O dataset 2019 tem formato: {df_fim2019.shape}')
print(f'O dataset 2020 tem formato: {df_fim2020.shape}')
print(f'O dataset 2021 tem formato: {df_fim2021.shape}')
print(f'O dataset 2022 tem formato: {df_fim2022.shape}')
print(f'O dataset 2023 tem formato: {df_fim2023.shape}')
print(f'O dataset 2024 tem formato: {df_fim2024.shape}')
# Out:
# O dataset 2018 tem formato: (951, 25)
# O dataset 2019 tem formato: (1881, 25)
# O dataset 2020 tem formato: (1368, 25)
# O dataset 2021 tem formato: (1625, 23)
# O dataset 2022 tem formato: (2072, 24)
# O dataset 2023 tem formato: (718, 26)
# O dataset 2024 tem formato: (1734, 27)

# %% [markdown]
# ### Verficando nome das colunas

# %%
df_fim2018.columns.equals(df_fim2019.columns)
# Out:
# True

# %%
df_fim2018.columns.equals(df_fim2020.columns)
# Out:
# True

# %%
df_fim2020.columns
# Out:
# Index(['Agente  Causador  Acidente', 'Data Acidente', 'CBO', 'CBO.1', 'CID-10',
#        'CID-10.1', 'CNAE2.0 Empregador', 'CNAE2.0 Empregador.1',
#        'Emitente CAT', 'Espécie do benefício', 'Filiação Segurado',
#        'Indica acidente', 'Munic Empr', 'Natureza da Lesão',
#        'Origem de Cadastramento CAT', 'Parte Corpo Atingida', 'Sexo',
#        'Tipo do Acidente', 'UF  Munic.  Acidente', 'UF Munic. Empregador',
#        'Data  Afastamento', 'Data Despacho Benefício', 'Data Acidente.1',
#        'Data Nascimento', 'Data Emissão CAT'],
#       dtype='object')

# %%
df_fim2021.columns
# Out:
# Index(['Agente  Causador  Acidente', 'CBO', 'CID-10', 'CNAE2.0 Empregador',
#        'CNAE2.0 Empregador.1', 'Emitente CAT', 'Espécie do benefício',
#        'Filiação Segurado', 'Indica Óbito Acidente', 'Munic Empr',
#        'Natureza da Lesão', 'Origem de Cadastramento CAT',
#        'Parte Corpo Atingida', 'Sexo', 'Tipo do Acidente',
#        'UF  Munic.  Acidente', 'UF Munic. Empregador', 'Data Acidente.1',
#        'Data Despacho Benefício', 'Data Acidente.2', 'Data Nascimento',
#        'Data Emissão CAT', 'CNPJ/CEI Empregador'],
#       dtype='object')

# %%
df_fim2020['Data Acidente']
# Out:
# 585          2020/01
# 592          2020/01
# 1052         2020/01
# 1119         2020/01
# 1155         2020/01
#              ...
# 116404    01/12/2020
# 116415    01/12/2020
# 116482    01/12/2020
# 116573    01/12/2020
# 116872    01/10/2020
# Name: Data Acidente, Length: 1368, dtype: object

# %%
df_fim2020['Data Acidente.1']
# Out:
# 585       02/01/2020
# 592       03/01/2020
# 1052      04/01/2020
# 1119      04/01/2020
# 1155      03/01/2020
#              ...
# 116404    05/12/2020
# 116415    14/12/2020
# 116482    30/12/2020
# 116573    18/12/2020
# 116872    05/10/2020
# Name: Data Acidente.1, Length: 1368, dtype: object

# %%
#df_fim2021['Data Acidente']

# %%
df_fim2021['Data Acidente.1']
# Out:
# 146      2021/01
# 282      2021/01
# 598      2021/01
# 615      2021/01
# 900      2021/01
#           ...
# 94988    2021/12
# 95121    2021/12
# 95343    2021/12
# 95442    2021/12
# 95540    2021/12
# Name: Data Acidente.1, Length: 1625, dtype: object

# %%
df_fim2021['Data Acidente.2']
# Out:
# 146      01/01/2021
# 282      03/01/2021
# 598      03/01/2021
# 615      02/01/2021
# 900      04/01/2021
#             ...
# 94988    29/12/2021
# 95121    30/12/2021
# 95343    30/12/2021
# 95442    30/12/2021
# 95540    29/12/2021
# Name: Data Acidente.2, Length: 1625, dtype: object

# %%
df_fim2021.rename(columns={'Data Acidente.1': 'Data Acidente'}, inplace = True)
df_fim2021.rename(columns={'Data Acidente.2': 'Data Acidente.1'}, inplace = True)
df_fim2021.rename(columns={'Indica Óbito Acidente': 'Indica acidente'}, inplace = True)
# Out:
# C:\Users\isabe\AppData\Local\Temp\ipykernel_1952\266231916.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fim2021.rename(columns={'Data Acidente.1': 'Data Acidente'}, inplace = True)
# C:\Users\isabe\AppData\Local\Temp\ipykernel_1952\266231916.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fim2021.rename(columns={'Data Acidente.2': 'Data Acidente.1'}, inplace = True)
# C:\Users\isabe\AppData\Local\Temp\ipykernel_1952\266231916.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df_fim2021.columns
# Out:
# Index(['Agente  Causador  Acidente', 'CBO', 'CID-10', 'CNAE2.0 Empregador',
#        'CNAE2.0 Empregador.1', 'Emitente CAT', 'Espécie do benefício',
#        'Filiação Segurado', 'Indica acidente', 'Munic Empr',
#        'Natureza da Lesão', 'Origem de Cadastramento CAT',
#        'Parte Corpo Atingida', 'Sexo', 'Tipo do Acidente',
#        'UF  Munic.  Acidente', 'UF Munic. Empregador', 'Data Acidente',
#        'Data Despacho Benefício', 'Data Acidente.1', 'Data Nascimento',
#        'Data Emissão CAT', 'CNPJ/CEI Empregador'],
#       dtype='object')

# %% [markdown]
# df_fim2021 não tem CBO.1 e CID-10.1

# %%
df_fim2022.columns
# Out:
# Index(['Agente  Causador  Acidente', 'Data Acidente', 'CBO', 'CID-10',
#        'CNAE2.0 Empregador', 'CNAE2.0 Empregador.1', 'Emitente CAT',
#        'Espécie do benefício', 'Filiação Segurado', 'Indica Óbito Acidente',
#        'Munic Empr', 'Natureza da Lesão', 'Origem de Cadastramento CAT',
#        'Parte Corpo Atingida', 'Sexo', 'Tipo do Acidente',
#        'UF  Munic.  Acidente', 'UF Munic. Empregador', 'Data Acidente.1',
#        'Data Despacho Benefício', 'Data Acidente.2', 'Data Nascimento',
#        'Data Emissão CAT', 'CNPJ/CEI Empregador'],
#       dtype='object')

# %%
df_fim2022['Data Acidente']
# Out:
# 1320     2022/02
# 1942     2022/02
# 2133     2022/01
# 2134     2022/02
# 2406     2022/03
#           ...
# 24719    2022/12
# 25182    2022/11
# 25231    2022/11
# 25361    2022/12
# 25386    2022/12
# Name: Data Acidente, Length: 2072, dtype: object

# %%
df_fim2022['Data Acidente.1']
# Out:
# 1320     2022/02
# 1942     2022/02
# 2133     2022/01
# 2134     2022/02
# 2406     2022/03
#           ...
# 24719    2022/12
# 25182    2022/11
# 25231    2022/11
# 25361    2022/12
# 25386    2022/12
# Name: Data Acidente.1, Length: 2072, dtype: object

# %%
df_fim2022['Data Acidente.2']
# Out:
# 1320     17/02/2022
# 1942     25/02/2022
# 2133     20/01/2022
# 2134     15/02/2022
# 2406     02/03/2022
#             ...
# 24719    28/12/2022
# 25182    21/11/2022
# 25231    25/11/2022
# 25361    29/12/2022
# 25386    30/12/2022
# Name: Data Acidente.2, Length: 2072, dtype: object

# %%
df_fim2022.drop(['Data Acidente.1'], axis=1, inplace = True)
# Out:
# C:\Users\isabe\AppData\Local\Temp\ipykernel_1952\2880707795.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fim2022.drop(['Data Acidente.1'], axis=1, inplace = True)

# %%
df_fim2022.rename(columns={'Data Acidente.2': 'Data Acidente.1'}, inplace = True)
df_fim2022.rename(columns={'Indica Óbito Acidente': 'Indica acidente'}, inplace = True)
# Out:
# C:\Users\isabe\AppData\Local\Temp\ipykernel_1952\150514130.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fim2022.rename(columns={'Data Acidente.2': 'Data Acidente.1'}, inplace = True)
# C:\Users\isabe\AppData\Local\Temp\ipykernel_1952\150514130.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fim2022.rename(columns={'Indica Óbito Acidente': 'Indica acidente'}, inplace = True)

# %%
df_fim2023.columns
# Out:
# Index(['Agente  Causador  Acidente', 'CBO', 'CID-10', 'CNAE2.0 Empregador',
#        'CNAE2.0 Empregador.1', 'Emitente CAT', 'Espécie do benefício',
#        'Filiação Segurado', 'Indica Óbito Acidente', 'Munic Empr',
#        'Natureza da Lesão', 'Origem de Cadastramento CAT',
#        'Parte Corpo Atingida', 'Sexo', 'Tipo do Acidente',
#        'UF  Munic.  Acidente', 'UF Munic. Empregador',
#        'Data Despacho Benefício', 'Data Acidente.1', 'Data Nascimento',
#        'Data Emissão CAT', 'CNPJ/CEI Empregador', 'CBO.1', 'CID-10.1',
#        'Data  Afastamento', 'Tipo de Empregador'],
#       dtype='object')

# %%
df_fim2023.rename(columns={'Indica Óbito Acidente': 'Indica acidente'}, inplace = True)
# Out:
# C:\Users\isabe\AppData\Local\Temp\ipykernel_1952\538714696.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fim2023.rename(columns={'Indica Óbito Acidente': 'Indica acidente'}, inplace = True)

# %% [markdown]
# df_fim23 não tem acidente 0

# %%
df_fim2024.columns
# Out:
# Index(['Agente  Causador  Acidente', 'Data Acidente', 'CBO', 'CBO.1', 'CID-10',
#        'CID-10.1', 'CNAE2.0 Empregador', 'CNAE2.0 Empregador.1',
#        'Emitente CAT', 'Espécie do benefício', 'Filiação Segurado',
#        'Indica Óbito Acidente', 'Munic Empr', 'Natureza da Lesão',
#        'Origem de Cadastramento CAT', 'Parte Corpo Atingida', 'Sexo',
#        'Tipo do Acidente', 'UF  Munic.  Acidente', 'UF Munic. Empregador',
#        'Data  Afastamento', 'Data Despacho Benefício', 'Data Acidente.1',
#        'Data Nascimento', 'Data Emissão CAT', 'Tipo de Empregador',
#        'CNPJ/CEI Empregador'],
#       dtype='object')

# %%
df_fim2024.rename(columns={'Indica Óbito Acidente': 'Indica acidente'}, inplace = True)
# Out:
# C:\Users\isabe\AppData\Local\Temp\ipykernel_1952\3597806496.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fim2024.rename(columns={'Indica Óbito Acidente': 'Indica acidente'}, inplace = True)

# %%
df_fim2024['Data Acidente.1']
# Out:
# 149      02/01/2024
# 186      02/01/2024
# 568      02/01/2024
# 656      03/01/2024
# 1356     03/01/2024
#             ...
# 34304    16/08/2024
# 34512    15/08/2024
# 34733    16/08/2024
# 34942    17/08/2024
# 35916    18/08/2024
# Name: Data Acidente.1, Length: 1734, dtype: object

# %%
df_final = pd.concat([df_fim2018, df_fim2019, df_fim2020, df_fim2021, df_fim2022, df_fim2023, df_fim2024])

# %%
print(f"O dataframe final tem {df_final.shape} ")
# Out:
# O dataframe final tem (10349, 27)

# %%
df_final.head(6)
# Out:
#      Agente  Causador  Acidente Data Acidente     CBO                 CBO.1  \
# 681        Madeira (Toro, Madei        201807  782515  782515-Motorista Ope
# 709        Fogo-Chama,Material         201807  862150  862150-Oper. Máquina
# 716        Cadeira Banco - Mobi        201806  123110  123110-Dir. Administ
# 998        Ferramenta Manual se        201806  514325  {ñ class}
# 1512       Laminadora, Calandra        201806  862150  862150-Oper. Máquina
# 1742       Particulas - nao Ide        201806  514320  {ñ class}
#
#       CID-10              CID-10.1  CNAE2.0 Empregador  CNAE2.0 Empregador.1  \
# 681   W22     W22   Impacto Acid A                4930  Transporte Rodoviari
# 709   T252    T25.2 Queim de 2.Gra                2422  Producao de Laminado
# 716   S635    S63.5 Entorse e Dist                8411  Administracao Public
# 998   Z209    Z20.9 Contato Exposi                8121  Limpeza em Predios e
# ...

# %%
df_final.tail(6)
# Out:
#       Agente  Causador  Acidente Data Acidente     CBO                 CBO.1  \
# 34255       Chao - Superficie Ut    14/08/2024  725030  {ñ class}
# 34304       Caixa, Engradado, Ca    16/08/2024  414125  {ñ class}
# 34512       Tubo, Manilha - Cera    15/08/2024  784205  784205-Alimentador d
# 34733       Piso de Veiculo - Su    16/08/2024  414105  414105-Almoxarife
# 34942       Rua e Estrada - Supe    17/08/2024  519110  519110-Motociclista
# 35916       Escada Permanente Cu    18/08/2024  414125  {ñ class}
#
#        CID-10              CID-10.1  CNAE2.0 Empregador  CNAE2.0 Empregador.1  \
# 34255  L989    L98.9 Afeccoes da Pe                3321  Instalacao de Maquin
# 34304  S611    S61.1 Ferim de Dedos                4530  Comercio de Pecas e
# 34512  S519    S51.9 Ferim do Anteb                2593  Fabricacao de Artigo
# 34733  M238    M23.8 Outr Transt In                4771  Comercio Varejista d
# ...

# %% [markdown]
# ### Filtragem no dataset final

# %%
df_final.columns
# Out:
# Index(['Agente  Causador  Acidente', 'Data Acidente', 'CBO', 'CBO.1', 'CID-10',
#        'CID-10.1', 'CNAE2.0 Empregador', 'CNAE2.0 Empregador.1',
#        'Emitente CAT', 'Espécie do benefício', 'Filiação Segurado',
#        'Indica acidente', 'Munic Empr', 'Natureza da Lesão',
#        'Origem de Cadastramento CAT', 'Parte Corpo Atingida', 'Sexo',
#        'Tipo do Acidente', 'UF  Munic.  Acidente', 'UF Munic. Empregador',
#        'Data  Afastamento', 'Data Despacho Benefício', 'Data Acidente.1',
#        'Data Nascimento', 'Data Emissão CAT', 'CNPJ/CEI Empregador',
#        'Tipo de Empregador'],
#       dtype='object')

# %%
df_final['CBO'].value_counts()
# Out:
# CBO
# 322205                                           565
# {ñ class}                                        519
# 322205-Tec. de Enfermagem                        441
# 784205                                           275
# 784205-Alimentador de Linha de Prod.             251
#                                                 ...
# 723310-Pintor Pincel e Rolo (Exceto Obras e E      1
# 710125-Superv. Transporte na Mineração             1
# 823315-Forneiro (Materiais de Construção)          1
# 410215-Superv. Contas a Pagar                      1
# 773325-Oper. de Máquina de Usinagem Madeira,       1
# Name: count, Length: 952, dtype: int64

# %%
df_final['CBO.1'].value_counts()
# Out:
# CBO.1
# 322205-Tec. de Enfer    565
# {ñ class}               438
# 784205-Alimentador d    275
# 911305-Mec. Manut. M    199
# 782510-Motorista de     178
#                        ...
# 413225-Escriturário       1
# 950110-Superv. Manut      1
# 123110-Dir. Administ      1
# 413105-Analista Folh      1
# 992220-Pedreiro de C      1
# Name: count, Length: 540, dtype: int64

# %%
cbo =df_final['CBO.1'].unique()
cbo2 =df_final['CBO'].unique()

# %%
#np.savetxt("cbdo.csv", cbo2, delimiter=",", fmt="% s")

# %%
df_final['CID-10']
# Out:
# 681      W22
# 709      T252
# 716      S635
# 998      Z209
# 1512     S600
#           ...
# 34304    S611
# 34512    S519
# 34733    M238
# 34942    V299
# 35916    R520
# Name: CID-10, Length: 10349, dtype: object

# %%
df_final['CID-10.1']
# Out:
# 681      W22   Impacto Acid A
# 709      T25.2 Queim de 2.Gra
# 716      S63.5 Entorse e Dist
# 998      Z20.9 Contato Exposi
# 1512     S60.0 Contusao de De
#                  ...
# 34304    S61.1 Ferim de Dedos
# 34512    S51.9 Ferim do Anteb
# 34733    M23.8 Outr Transt In
# 34942    V29.9 Motociclista A
# 35916    R52.0 Dor Aguda
# Name: CID-10.1, Length: 10349, dtype: object

# %%
df_final.dtypes
# Out:
# Agente  Causador  Acidente     object
# Data Acidente                  object
# CBO                            object
# CBO.1                          object
# CID-10                         object
# CID-10.1                       object
# CNAE2.0 Empregador              int64
# CNAE2.0 Empregador.1           object
# Emitente CAT                   object
# Espécie do benefício           object
# Filiação Segurado              object
# Indica acidente                object
# Munic Empr                     object
# Natureza da Lesão              object
# Origem de Cadastramento CAT    object
# Parte Corpo Atingida           object
# Sexo                           object
# Tipo do Acidente               object
# UF  Munic.  Acidente           object
# UF Munic. Empregador           object
# Data  Afastamento              object
# Data Despacho Benefício        object
# Data Acidente.1                object
# Data Nascimento                object
# Data Emissão CAT               object
# ...

# %%
df_final['CBO'].replace('{ñ class}                                    ', 'Não Disponível', inplace=True)
# Out:
# C:\Users\isabe\AppData\Local\Temp\ipykernel_1952\672145909.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_final['CBO'].replace('{ñ class}                                    ', 'Não Disponível', inplace=True)

# %%
#df_final.to_csv('dfteste_cbosujo.csv')

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [162], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
df_final = pd.read_csv('dfteste1 - dfteste1.csv.csv', encoding= 'ISO-8859-1')

# %% [markdown]
# ## Arrumando colunas e termos

# %%
df_final.head()
# Out:
#    Unnamed: 0 Agente  Causador  Acidente Data Acidente     CBO  \
# 0         716       Cadeira Banco - Mobi        201806  123110
# 1        1512       Laminadora, Calandra        201806  862150
# 2        1742       Particulas - nao Ide        201806  514320
# 3        2134       Ferramenta Manual se        201807  322205
# 4        2140       Veiculo Rodoviario M        201807  421125
#
#                    CBO.1 CID-10              CID-10.1  CNAE2.0 Empregador  \
# 0   123110-Dir. Administ   S635  S63.5 Entorse e Dist                8411
# 1  862150-Oper. MÃ¡quina   S600  S60.0 Contusao de De                2854
# 2             {Ã± class}   S610  S61.0 Ferim de Dedos                8129
# 3   322205-Tec. de Enfer   K251  K25.1 Aguda c/Perfur                8610
# 4     421125-Oper. Caixa   M542     M54.2 Cervicalgia                5611
#
#    CNAE2.0 Empregador.1 Emitente CAT  ... Tipo do Acidente  \
# 0  Administracao Public   Empregador  ...          TÃ­pico
# ...

# %%
df_finall.drop(['Unnamed: 0'], axis=1, inplace = True)

# %%
df_finall.head()
# Out:
#   Agente  Causador  Acidente Data Acidente     CBO                  CBO.1  \
# 0       Cadeira Banco - Mobi        201806  123110   123110-Dir. Administ
# 1       Laminadora, Calandra        201806  862150  862150-Oper. MÃ¡quina
# 2       Particulas - nao Ide        201806  514320             {Ã± class}
# 3       Ferramenta Manual se        201807  322205   322205-Tec. de Enfer
# 4       Veiculo Rodoviario M        201807  421125     421125-Oper. Caixa
#
#   CID-10              CID-10.1  CNAE2.0 Empregador  CNAE2.0 Empregador.1  \
# 0   S635  S63.5 Entorse e Dist                8411  Administracao Public
# 1   S600  S60.0 Contusao de De                2854  Fabricacao de Maquin
# 2   S610  S61.0 Ferim de Dedos                8129  Atividades de Limpez
# 3   K251  K25.1 Aguda c/Perfur                8610  Atividades de Atendi
# 4   M542     M54.2 Cervicalgia                5611  Restaurantes e Outro
#
#   Emitente CAT EspÃ©cie do benefÃ­cio  ... Tipo do Acidente  \
# ...

# %%
df_finall['CBO'] = df_finall['CBO'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 df_finall['CBO'] = df_finall['CBO'].astype(int)
#
# NameError: name 'df_finall' is not defined

# %%
profissoes = [862150, 724410, 721210, 911305, 821405, 314615, 724435,
784205, 725505, 391205, 414110, 720210, 313120, 214905,
724220, 782220, 782115, 351605, 721225, 725105, 813125,
391215, 314410, 731175, 391115, 821445, 725205, 720110,
723320, 731135, 725015, 953115, 314120, 910130, 300305,
821310, 391125, 722330, 313410, 811010, 731120, 821450,
214305, 214505, 314110, 810105, 721420, 724510, 910105,
314305, 915105, 724515, 813120, 711210, 782130, 725510,
723120, 810110, 214405, 722415, 313415, 301105, 721325,
391210, 725005, 721220, 950305, 813115, 911325]

#dataset = df_finall[df_finall['CBO'].isin(profissoes)]

#display(dataset)
# Out:
#      Agente  Causador  Acidente Data Acidente     CBO                  CBO.1  \
# 1          Laminadora, Calandra        201806  862150  862150-Oper. MÃ¡quina
# 5                   Animal Vivo        201806  724410   724410-Caldeireiro (
# 8          Embalagem e Recipien        201807  721210  721210-Oper. MÃ¡quina
# 9           Metal - Inclui Liga        201807  911305   911305-Mec. Manut. M
# 11         Alicate, Torques, Te        201807  821405   821405-Encarregado d
# ...                         ...           ...     ...                    ...
# 2276       Piso de Edificio - S    26/07/2024  391125   391125-Tec. Planejam
# 2281       Maquina, Nic            30/07/2024  784205   784205-Alimentador d
# 2282        Metal - Inclui Liga    30/07/2024  862150  862150-Oper. MÃ¡quina
# 2290        Metal - Inclui Liga    30/07/2024  300305   300305-Tec. Eletrome
# 2294       Ferramenta, Maquina,    07/08/2024  862150  862150-Oper. MÃ¡quina
#
# ...

# %%
dataset.columns
# Out:
# Index(['Agente  Causador  Acidente', 'Data Acidente', 'CBO', 'CBO.1', 'CID-10',
#        'CID-10.1', 'CNAE2.0 Empregador', 'CNAE2.0 Empregador.1',
#        'Emitente CAT', 'Espécie do benefício', 'Filiação Segurado',
#        'Indica acidente', 'Munic Empr', 'Natureza da Lesão',
#        'Origem de Cadastramento CAT', 'Parte Corpo Atingida', 'Sexo',
#        'Tipo do Acidente', 'UF  Munic.  Acidente', 'UF Munic. Empregador',
#        'Data  Afastamento', 'Data Despacho Benefício', 'Data Acidente.1',
#        'Data Nascimento', 'Data Emissão CAT', 'CNPJ/CEI Empregador',
#        'Tipo de Empregador'],
#       dtype='object')

# %%
dataset.rename(columns={'FiliaÃ§Ã£o Segurado': 'Filiação Segurado'}, inplace = True)
dataset.rename(columns={'EspÃ©cie do benefÃ­cio': 'Espécie do benefício'}, inplace = True)
dataset.rename(columns={'Data Despacho BenefÃ­cio': 'Data Despacho Benefício'}, inplace = True)
dataset.rename(columns={'Data EmissÃ£o CAT': 'Data Emissão CAT'}, inplace = True)
dataset.rename(columns={'Natureza da LesÃ£o': 'Natureza da Lesão'}, inplace = True)
# Out:
# C:\Users\isabe\AppData\Local\Temp\ipykernel_12036\1254236181.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.rename(columns={'FiliaÃ§Ã£o Segurado': 'Filiação Segurado'}, inplace = True)
# C:\Users\isabe\AppData\Local\Temp\ipykernel_12036\1254236181.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.rename(columns={'EspÃ©cie do benefÃ­cio': 'Espécie do benefício'}, inplace = True)
# C:\Users\isabe\AppData\Local\Temp\ipykernel_12036\1254236181.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
dataset.columns
# Out:
# Index(['Agente  Causador  Acidente', 'Data Acidente', 'CBO', 'CBO.1', 'CID-10',
#        'CID-10.1', 'CNAE2.0 Empregador', 'CNAE2.0 Empregador.1',
#        'Emitente CAT', 'Espécie do benefício', 'Filiação Segurado',
#        'Indica acidente', 'Munic Empr', 'Natureza da Lesão',
#        'Origem de Cadastramento CAT', 'Parte Corpo Atingida', 'Sexo',
#        'Tipo do Acidente', 'UF  Munic.  Acidente', 'UF Munic. Empregador',
#        'Data  Afastamento', 'Data Despacho Benefício', 'Data Acidente.1',
#        'Data Nascimento', 'Data Emissão CAT', 'CNPJ/CEI Empregador',
#        'Tipo de Empregador'],
#       dtype='object')

# %%
print(f'O tamanho do dataset final e filtrado é: {dataset.shape}')
print(f'Enquanto o tamanho do dataset anterior era: {df_finall.shape}')
# Out:
# O tamanho do dataset final e filtrado é: (637, 27)
# Enquanto o tamanho do dataset anterior era: (2309, 27)

# %%
dataset['Natureza da Lesão'].value_counts()
# Out:
# Natureza da Lesão
# Corte, Laceracao, Fe                             144
# Contusao, Esmagament                             114
# Fratura                                           87
# Corte, Laceracao, Ferida Contusa, Punctura        47
# Luxacao                                           45
# Distensao, Torcao                                 31
# Lesao Imediata                                    21
# Escoriacao, Abrasao                               19
# Lesao Imediata, Nic                               18
# Contusao, Esmagamento (Superficie Cutanea I       18
# Queimadura ou Escald                              15
# Distensao, Torcao                                 13
# Lesoes Multiplas                                  11
# Escoriacao, Abrasao (Ferimento Superficial)       10
# Queimadura ou Escaldadura - Efeito de Tempe        9
# Lesao Imediata, Nic                                7
# Queimadura Quimica (                               4
# ...

# %%
dataset['CID-10'].value_counts()
# Out:
# CID-10
# S600    30
# S610    30
# S626    29
# S619    19
# S611    18
#         ..
# Y286     1
# S981     1
# S000     1
# S422     1
# T151     1
# Name: count, Length: 254, dtype: int64

# %%
dataset['Tipo do Acidente'].value_counts()
# Out:
# Tipo do Acidente
# TÃ­pico      471
# Trajeto       85
# TÃÂ­pico     72
# DoenÃ§a        9
# Name: count, dtype: int64

# %%
dataset['Tipo do Acidente'].replace('TÃ­pico', 'Típico', inplace=True)
dataset['Tipo do Acidente'].replace('TÃÂ­pico', 'Típico', inplace=True)
dataset['Tipo do Acidente'].replace('DoenÃ§a', 'Doença', inplace=True)
# Out:
# C:\Users\isabe\AppData\Local\Temp\ipykernel_12036\1890759210.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['Tipo do Acidente'].replace('TÃ­pico', 'Típico', inplace=True)
# C:\Users\isabe\AppData\Local\Temp\ipykernel_12036\1890759210.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
dataset['Tipo do Acidente'].value_counts()
# Out:
# Tipo do Acidente
# Típico     543
# Trajeto     85
# Doença       9
# Name: count, dtype: int64

# %%
dataset['Data Acidente']
# Out:
# 1           201806
# 5           201806
# 8           201807
# 9           201807
# 11          201807
#            ...
# 2276    26/07/2024
# 2281    30/07/2024
# 2282    30/07/2024
# 2290    30/07/2024
# 2294    07/08/2024
# Name: Data Acidente, Length: 637, dtype: object

# %%
dataset['Data Acidente.1']
# Out:
# 1       30/06/2018
# 5       29/06/2018
# 8       03/07/2018
# 9       04/07/2018
# 11      04/07/2018
#            ...
# 2276    26/07/2024
# 2281    30/07/2024
# 2282    30/07/2024
# 2290    30/07/2024
# 2294    07/08/2024
# Name: Data Acidente.1, Length: 637, dtype: object

# %%
dataset.drop(['Data Acidente'], axis=1, inplace = True)
# Out:
# C:\Users\isabe\AppData\Local\Temp\ipykernel_12036\1864262900.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.drop(['Data Acidente'], axis=1, inplace = True)

# %%
dataset.rename(columns={'Indica acidente': 'Indica Óbito Acidente'}, inplace = True)
dataset.rename(columns={'Data Acidente.1': 'Data Acidente'}, inplace = True)
# Out:
# C:\Users\isabe\AppData\Local\Temp\ipykernel_12036\1081320658.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.rename(columns={'Indica acidente': 'Indica Óbito Acidente'}, inplace = True)
# C:\Users\isabe\AppData\Local\Temp\ipykernel_12036\1081320658.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.rename(columns={'Data Acidente.1': 'Data Acidente'}, inplace = True)

# %%
dataset['Agente  Causador  Acidente'].unique()
# Out:
# array(['Laminadora, Calandra', 'Animal Vivo', 'Embalagem e Recipien',
#        'Metal - Inclui Liga', 'Alicate, Torques, Te',
#        'Ferramenta, Maquina,', 'Maquina de Aparafusa',
#        'Alavanca, Pe-De-Cabr', 'Caixa, Engradado, Ca',
#        'Macaco (Mecanico, Hi', 'Martelo, Malho, Marr',
#        'Equip. de Iluminacao', 'Vestuario, Nic      ',
#        'Motocicleta, Motonet', 'Veiculo Rodoviario M',
#        'Canal, Fosso        ', 'Andaime, Plataforma ',
#        'Agua - Usar Quando O', 'Veiculo, Nic        ',
#        'Ferramenta de Soldag', 'Tapete, Forracao de ',
#        'Sucata, Entulho, Res', 'Chao - Superficie Ut',
#        'Esmeril- Ferramenta', 'Deposito Fixo (Tanqu',
#        'Inalacao, Ingestao o', 'Transportador, Nic  ',
#        'Rebitadeira- Ferrame', 'Esforco Excessivo ao',
#        'Dispositivo de Trans', 'Empilhadeira', 'Maquina, Nic        ',
#        'Vidraria, Fibra de V', 'Faca, Facao- Ferrame',
#        'Balcao, Bancada - Mo', 'Piso de Veiculo - Su',
# ...

# %%
dataset['Agente  Causador  Acidente'].value_counts()
# Out:
# Agente  Causador  Acidente
# Metal - Inclui Liga                              92
# Ferramenta, Maquina,                             43
# Veiculo Rodoviario M                             30
# Metal - Inclui Liga Ferrosa e nao Ferrosa, Tu    25
# Maquina, Nic                                     17
#                                                  ..
# Maquina de Costurar e de Pespontar                1
# Serra, Serrote- Ferr                              1
# Arquivo, Fichario, E                              1
# Perfuratriz- Ferrame                              1
# Piso de Edificio - S                              1
# Name: count, Length: 155, dtype: int64

# %%
#dataset.to_csv('dataset1.csv')
